# %%
import pandas as pd
import numpy as np
from functools import reduce
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.feature_extraction import stop_words
 
whole = pd.read_csv('complete_allbrands_users_captions_list.csv', encoding="latin-1")
whole = whole[whole['followers_count']>10000]
whole = whole[whole['followers_count']<100000]

data = whole

# %%
# This is not going to run
user = pd.read_csv('30users.csv')
k = list(user.jenniferyoungstudio)
k.append('jenniferyoungstudio')
k = pd.DataFrame(k, columns= ['username'])
k['joined'] = 1
result = pd.merge(k, data, on='username', how='outer')



data = result[result.joined==1]
data = data.dropna(axis=0, how='any')
data = (data.drop_duplicates(subset=['username'], keep='first')).reset_index()

# %%
hashtags = []
for i,v in enumerate(data.caption):
    tags = v
    k = {tag.strip("#") for tag in tags.split() if tag.startswith("#")}
    hashtags.append(k)

# %%
hashtags
# Out:
# [{'3',
#   '5months',
#   'ArtAlive2017',
#   'Austin',
#   'BCBG',
#   'BLOOMBASH',
#   'Baywatch',
#   'Bejewled',
#   'BloomBash',
#   'Breathtaking',
#   'Burgers',
#   "CantStopSmiling',",
#   'ClassicLeather',
#   'Cruella',
#   "DMTC',",
#   'DayatFashionValley',
#   'DelMarRacing',
#   'DelMarScene',
#   'Epic48',
#   'Epic48Hours',
#   "Epic48Hours',",
#   "F21xMe',",
#   'FWSD',
#   'FourthofJuly',
#   'France',
#   'G6',
#   'GG2017"]',
#   'GNO',
#   'Hair',
#   'Halloween',
#   'HotelDel',
#   'KAABOO',
#   'KAABOO2017',
#   'KEXfest',
#   'KSsandiego',
#   'Kaaboo',
#   'LTKBag',
#   'LTKBeauty',
#   'LTKShoeCrush',
#   'LTKShoeCrush",',
#   'LTKStyleTip',
#   'LTKbeauty',
#   'LTKbeauty",',
#   'LTKbump',
#   'LTKitbag',
#   'LTKitbag",',
#   "LTKitbag',",
#   'LTKsalealert',
#   "LTKsalealert',",
#   'LTKshoecrush',
#   'LTKshoecrush",',
#   'LTKstyletip',
#   'LTKswim',
#   'LTKunder100',
#   'LTKunder50',
#   'LTKunder50",',
#   'Love',
#   "Love',",
#   'LoveTatum',
#   'MBELCAJONLIVE',
#   'MBELCAJONLive',
#   'MBatKAABOO',
#   'MBelcajon',
#   'MMC',
#   'Mammoth',
#   'Married4Months",',
#   'Mercedes',
#   'MexicanEatingMexican',
#   'MotherDaughter",',
#   'MothersDayatFV',
#   'MothersDayatFV",',
#   'MrsMoorten',
#   'NMbeauty',
#   'NMevents',
#   'NMshoelove',
#   'NMyum',
#   'OOTD',
#   'OnlyatNM',
#   'OntheCusp',
#   'PalmSprings',
#   'Paris',
#   'ParisBaby',
#   "RedORestaurant',",
#   'RyanandNelya',
#   'SD',
#   'SamsungGalaxy',
#   'SanDiego',
#   'SanDiegoMuseumOfArt',
#   'SdinHD',
#   'ShakeShack',
#   'TedBaker',
#   'TedBaker",',
#   "TedBaker',",
#   'TedToToe',
#   'TedToToe",',
#   'TheMoortens",',
#   'ThisIsHowWeDoIt',
#   "UTC',",
#   "VB',",
#   'VIBRANCE',
#   'VIBRANCÉ',
#   'VRParis",',
#   'Verizon',
#   "Verizon',",
#   'accessories',
#   'ad',
#   'ad",',
#   'anniversary',
#   'arclight',
#   'babyfever',
#   'bachelorette',
#   'bacheloretteparty',
#   'balboapark',
#   'bananarepublic',
#   'baysidesummernights',
#   'beauty',
#   "beauty',",
#   'beepbeep',
#   'bff',
#   'bffs',
#   'blackonpink',
#   'blendinginwithnature',
#   'blessed',
#   'blog',
#   'blogger',
#   "bloggerbabes',",
#   'bloggerstyle',
#   'bloombash',
#   'bloomingdales',
#   'blush',
#   'bomber',
#   'bridalshower',
#   'bride',
#   'bridesmaids',
#   'brunette',
#   'brunettes',
#   'bsn201',
#   "bubbleumbrella',",
#   'buns',
#   'cabana',
#   "cabiscoop',",
#   'cake',
#   'cali',
#   'calligraphy',
#   'casademontevista',
#   'celebs',
#   'charity',
#   'cheers',
#   'colorlove',
#   'concert',
#   'coral',
#   'coronado',
#   'costumes',
#   'couplescostume',
#   'customwoodsign',
#   'datenight',
#   'delmar',
#   'delmarfair',
#   'delmarracetrack',
#   'designer',
#   'dessert',
#   'details',
#   "details',",
#   'discoverthedifference',
#   'disneyvillain',
#   'downtown",',
#   'dress',
#   'dressedtomatch',
#   'earrings',
#   "eatmorecake',",
#   'eiffeltower',
#   'esteelauder',
#   'fascinator',
#   'fashion',
#   'fashion",',
#   'fashionable',
#   'fashionblog',
#   'fashionista',
#   'fashionvalley",',
#   'fathersday',
#   'fauxfur',
#   'festival",',
#   'firsttimer',
#   'fitness',
#   'florals',
#   'flowercrowns',
#   'friends',
#   'fun',
#   "fun',",
#   'fwsd',
#   "fwsd',",
#   "gala',",
#   'galentines',
#   'girlfriends',
#   'girlsnightout',
#   'giveback',
#   'gno',
#   'goldenglobe',
#   'goldenglobesfashion',
#   'googlepixel',
#   'gowns',
#   'green',
#   'hair',
#   "hair',",
#   'halloween',
#   "halloweenmakeup',",
#   'hansolo',
#   'happilyevermoorten",',
#   'happy',
#   'happy",',
#   'happywife',
#   'harrypotter',
#   'hats',
#   'healthy',
#   'heels',
#   'helicopter',
#   'hellokitty',
#   'holiday',
#   'hollywoodfashion',
#   'hollywoodstyle',
#   'honeymoon',
#   'honeymoonnextweek',
#   'husband',
#   'iloveyou',
#   'inlove',
#   'inspo',
#   'instapic',
#   'isabelvianey#ootd",',
#   'itsbanana',
#   "jetaime',",
#   'justforfun",',
#   'kendrascott',
#   'kendrascottsd',
#   'kidatheart',
#   'kisses",',
#   'kssandiego',
#   'lajolla',
#   'liketkit',
#   'liketkit",',
#   "liketkit',",
#   'lipstick',
#   'littleitaly',
#   "loafers',",
#   'longhair',
#   'love',
#   'love",',
#   'lovelulus\\nJewelry',
#   'loveourteam',
#   'lovewillwin',
#   'lovewins',
#   'luxury',
#   'marchwedding',
#   'married',
#   "married',",
#   'marriedlife',
#   'matterinitup",',
#   'mcm',
#   'mercedes',
#   'merci',
#   'mmm',
#   'momentsoflife',
#   'monarch',
#   'moortenbotanicalgarden',
#   'moortens',
#   'mortoninthemorning',
#   'moviepremier',
#   'moviescreening',
#   'mrandmrs',
#   'mrs',
#   'mrsmoorten',
#   "mvmt',",
#   'mycoordinates',
#   'myfriendsaretalented',
#   'myheart',
#   'newlyweds',
#   'nightnight",',
#   'nightout',
#   'nike',
#   "nordstrom',",
#   'nordstromUTC',
#   'obsessed',
#   'ootd',
#   'ootn',
#   'padres',
#   'palmprint',
#   'palmsprings',
#   "palmsprings',",
#   'paris',
#   'party",',
#   'peace',
#   'peach',
#   'perfect',
#   'perfectday',
#   'personalstyle',
#   'personalstyle",',
#   'petcopark',
#   "petcopark',",
#   'photobomb',
#   'pieology',
#   'pink',
#   'poolside',
#   'prehoneymoon',
#   'princessleia',
#   'prospheresu',
#   'rain',
#   'rippedjeans',
#   'sandiego',
#   'sandiego",',
#   'sandiegostylist',
#   'sdso",',
#   'seaportvillage',
#   'shaky',
#   "sharemytargetstyle',",
#   'shine',
#   'shoes',
#   'sisters',
#   'soontobe',
#   'sponsored',
#   'spring',
#   "starwars',",
#   'staycation',
#   'strong',
#   'style',
#   'style",',
#   "style',",
#   'styleblogger',
#   'stylish',
#   'stylist',
#   'succulents',
#   'suitelife',
#   'sweets',
#   'tamales',
#   'tbt',
#   'tedbaker',
#   'tedtotoe',
#   'tedtotoe",',
#   'thebestornothing',
#   'thebestornothing\\u2028?',
#   'thisISclassic',
#   'torreypines',
#   'tower3",',
#   'travel',
#   'unicorncake",',
#   'vacay',
#   'vanessaballi',
#   'verizon',
#   'verizon",',
#   "verizon',",
#   'versailles',
#   'vibrance',
#   "vibrance',",
#   'wedding',
#   'wedding",',
#   'weddingcrasher',
#   'weddings',
#   'winter'},
#  {'ColdplayBangkok',
#   'DiorSS17',
#   "HAROLE',",
#   'HerRoom',
#   'Lightstruck',
#   'Realme',
#   'Shiseidovn',
#   'TETLOOPGIVEAWAY]\\nT?t',
#   'Tetloopgiveaway',
#   'Tetloopgiveaway\\n-',
#   'Tetloopgiveaway\\n------\\n-',
#   'WWDJFW',
#   "WWDJFW',",
#   'Wasobeauty',
#   'bambipose',
#   'beclubgiveaway",',
#   'bichchiteam',
#   'cocoonshow",',
#   'colorselfiecontest',
#   'concert',
#   'concert",',
#   "confetti',",
#   'contest",',
#   'donghopaulhewitt',
#   "fromneighborstobizzpartners',",
#   'halfempty',
#   'halffull',
#   "harole',",
#   'harole\\nÁo',
#   'highlighting',
#   'innisfreevietnam',
#   'lancomevietnam",',
#   'livepink',
#   'multimasking',
#   "onthebed',",
#   "onthetable',",
#   'ootd',
#   "strideby',",
#   "sundayfunday',",
#   'team??p",',
#   'tetloopgiveaway',
#   'tetloopgiveaway.',
#   "tetnaytamacaodai',",
#   'vocongkhanh',
#   'volcanicclay',
#   "wasoxbarcode',",
#   "watchme\\nhttp://amly.me/kz48',",
#   'wiwt",',
#   "zen',"},
#  {'countryside",',
#   "dewyskin#rosycheeks#glow#getthelook#mua#makeup#beautyaddict#muam#warsaw#warszawa#polska#poland#kolorowekredki#makeupmania#makeupmafia#vegas_nay#makeupslaves#makeupartist#slave2beauty#bestmuas#redlips#redlipsmakeup#makeupinspo#glam#CTYes']",
#   'girlswhofish',
#   "glow#jeffreestarcosmetics#jeffreestar#jeffreestarhighlighter#flawless#bestmuas#mua#makeup#beautyaddict#muam#warsaw#warszawa#polska#poland#kolorowekredki#makeupmania#makeupmafia#makeupartist#vegas_nay#makeupslaves#makeupartist#lipstick#slave2beauty',",
#   "gracja#glam#kyliecosmetics#ctilburymakeup#anastasiabeverlyhills#eyelashes#glow#makeup#beauty#poland#polska#bestmuas#muam#kolorowekredki#makeupslaves#vegas_nay#slave2beauty#bestmakeup#kolorowekredki#makeupart#makeupartist#tomfordbeauty',",
#   "lips#corallips#warsztaty#doseofcolors#workshops#charlottetilbury#beauty#poland#polska#beauty#bestmuas#muam#kolorowekredki#makeupslaves#vegas_nay#slave2beauty#bestmakeup#kolorowekredki#makeupheaven#lips#lipstick',",
#   "pout#orangelips#loreal#workshops#charlottetilbury#beauty#poland#polska#bestmuas#muam#kolorowekredki#makeupslaves#vegas_nay#slave2beauty#bestmakeup#kolorowekredki#makeupheaven#makeupart#makeupartist#cahrlottetilbury#tomfordbeauty',",
#   "pout#warsztaty#smokyeye#workshops#charlottetilbury#beauty#poland#polska#bestmuas#muam#kolorowekredki#makeupslaves#vegas_nay#slave2beauty#bestmakeup#kolorowekredki#makeupheaven#makeupart#makeupartist#cahrlottetilbury#tomfordbeauty',",
#   "secondlook#warsztaty#wroc?aw#smokyeye#workshops#charlottetilbury#beauty#poland#polska#beauty#bestmuas#muam#kolorowekredki#makeupslaves#vegas_nay#slave2beauty#bestmakeup#kolorowekredki#makeupheaven#lips#lipstick',",
#   "urbandecay#warsztaty#flawless#bestmuas#mua#makeup#beautyaddict#muam#warsaw#warszawa#polska#poland#kolorowekredki#makeupmania#makeupmafia#makeupartist#vegas_nay#makeupslaves#makeupartist#lipstick#slave2beauty#anastasiabeverlyhills',"},
#  {'ACoruña',
#   "AmyWinehouse',",
#   "AndyShauf',",
#   'AndyShauf\\n#CasiPeroNoSeMeVenLasBraguitas',
#   'ArcoirisLunar',
#   "ArethaFranklin',",
#   "AunqueEnMiGuaridaTampocoSientoLaOlaDeFrío',",
#   "BeginAgain',",
#   "BelleandSebastian',",
#   'BleedingBlue',
#   'BookOfLove',
#   "CaliforniaDreamin',",
#   'CameraObscura,',
#   'CasaDeLosSueños',
#   "ChrisStaples',",
#   'ClaudeDebussy',
#   "ColdWarKids',",
#   "CountingCrows',",
#   'Dalí',
#   "DanAuerbach',",
#   'DíaDelTrabajo',
#   'Díadelamúsica',
#   'ET',
#   'ElliottSmith\\n#FestivalDeLesArts',
#   'EverythingButTheGirl',
#   'Feist',
#   "FutureIslands\\n#Echodemenoselmar',",
#   'GeorgeBrassens',
#   'Godard',
#   "Goldmund',",
#   'HotelFinesterre',
#   'HotelFinesterre!\\n?:',
#   'JAKEBUGG',
#   "JRJR',",
#   "JoshRouse\\n#conun6yun4',",
#   'KingOfBeasts',
#   'LaMejorRehabilitacion\\n#SeQueHaceCalorParaGorretePeroTengoElOídoJodido',
#   'LaSera',
#   'Lachicaquedejasteatras\\nUn',
#   "LeanOnMe\\n#Telekinesis',",
#   "LeónLarregui',",
#   'MIAlegria\\n4?',
#   'Madrid',
#   'MisÚnicasSalidas',
#   "MusicforListeningToMusicTo',",
#   "Málaga',",
#   'NoHardFeelings',
#   'PaulTiernan\\n#misofáCasaTeléfono#AVerSiMeSubeElÁnimo#VayacaradeCrazy#YPelosDeLoquer#MisHermanasDicenQueSeMeVenLosOjosRaros',
#   'Reyes',
#   'ReyesMagos\\n¿Y',
#   'SaboreríaMahou',
#   'SanIsidro',
#   'SanJuan',
#   "SanValentín\\n#joyas#joyería#jewels#ring\\n#AAnnaKarinaLeEncanta',",
#   'SodaStereo\\n#peinaditos#aunquemesalenpachunpachan#mangalargaA36grados',
#   "SoulLegends\\n#YTengoOtraLlenaDeParchesQueMolaTodo#YaMismoOsLaEnseño',",
#   'SoyLaPequeDe8#MiFamiliaLamejor#papiroga',
#   "SuperTramp',",
#   'TengoDerecho#QuieroMimos#YUnSandwichDePollo#YUnaPeliGuay#ElPieMeDueleComoNadaNuncaEnMiVida',
#   "TheAvettBrothers',",
#   "TheSmiths',",
#   'TheSmiths\\nHe',
#   'TratameSuavemente',
#   'VIPLounge',
#   "Woods\\n#SanIsidro',",
#   "arabesques',",
#   'caloryfrío',
#   'celiacos',
#   'elle',
#   'espectáculo',
#   'exmagician',
#   'faceawards_es',
#   'fleetwoodmac',
#   'fullmetalshadow',
#   'girlsLoveCoruña',
#   'glutenfree',
#   "glutenfree',",
#   "glutenfree\\n@floridaretirooficial',",
#   'grupazo',
#   'heladeríaColón\\n#girlsLoveCoruña\\n#visitaCoruña',
#   "meniegoaponermeMediasaún',",
#   'mercadodesabores',
#   'miniOlgui',
#   "motorama\\n#enero#2017#mismuletasdefondosocool#calzas#triángulodelunares',",
#   'nosabesqueponerte',
#   'nyxcosmetics_es',
#   'otoño',
#   'patch',
#   "playon\\n#spotify',",
#   'retiro',
#   'spotify:',
#   'topchef',
#   'verano',
#   'verdejo',
#   'viejóvenes',
#   'vino',
#   'vino...',
#   'vivalavida\\nPlaying:',
#   "zoé',"},
#  {'20percentcounts',
#   'Ad',
#   "Ad',",
#   'BTS',
#   'BlackWomensEqualPayDay,',
#   'CCstylesummit.',
#   'CreateCultivateNYC,',
#   'CreateCultivateSEA',
#   'CreateCultivateSEA",',
#   "CreateCultivateSEA',",
#   'CreateCultivateSea',
#   'EqualPay',
#   'EqualPay\\xa0\\xa0#EqualityEveryDay',
#   "EqualisEqual',",
#   'Equalpay',
#   'EqualpayforEqualwork',
#   'Houston',
#   'LUNA',
#   'LUNAPartner',
#   'LUNAbar',
#   'LunaBar',
#   'LunaPartner',
#   'NewOriginals',
#   'STEM',
#   'WeKaulitHome',
#   'WeKaulitHome",',
#   "WeKaulitHome',",
#   'WeKaulitHome.',
#   'ad',
#   'ad",',
#   "ad',",
#   "allinadayswork',",
#   'badjokes',
#   'bosslife',
#   'cantstopwontstop',
#   'ccstylesummit',
#   "ccstylesummit',",
#   "ccxeddiebauer',",
#   'ccxmarriott',
#   "ccxmarriott',",
#   'cliniquexadler??tune',
#   'createcultivate100',
#   'createcultivate100",',
#   "createcultivate100',",
#   'createcultivateSEA!',
#   'createcultivatela',
#   "createcultivatela',",
#   'createcultivatenyc',
#   'createcultivatenyc!',
#   'createcultivatenyc",',
#   "createcultivatenyc',",
#   'createcultivatepopup',
#   'createcultivatesea',
#   'createcultivatesea!',
#   "createcultivatesea',",
#   'createcultivatesxsw',
#   "foundatsimon',",
#   'girlcrush',
#   'happyfathersday",',
#   'happymothersday',
#   'instagramhusband',
#   'internationalwomensday',
#   'justmorerp',
#   "justmorerp',",
#   'kaulifornialove',
#   'kaulifornialove",',
#   "kaulifornialove',",
#   'kinesthesia',
#   'kohlerideas',
#   'ladiesfirst',
#   "ladiesfirst',",
#   'legrandedame",',
#   "liveinperigold',",
#   "mahalo',",
#   'moreismore',
#   'mycb2',
#   "mycb2',",
#   'nationalpinkday',
#   'nationalpuppyday',
#   'nationalroséday',
#   'noahwiley.',
#   'nobummersummer',
#   'putaTARPonit',
#   'schoolofhustle',
#   "shethepeople',",
#   'shetopia,',
#   'smallacts",',
#   'somuchtodo',
#   'spotlight",',
#   'teamwontstop",',
#   "todayfeltlikea?',",
#   "travelbrilliantly',",
#   'udforwomen",',
#   "vcpoloclassic',",
#   'wekaulithome",',
#   "wekaulithome',",
#   'wheresthebear',
#   'womensequalityday!',
#   'womensmarch',
#   'workparty'},
#  {'TGIF',
#   'aiweiwei',
#   "andcut',",
#   "bebraveforyou',",
#   "bodybybrooklyn',",
#   "brancusi',",
#   'charlottesville',
#   'cinematic',
#   "commedesgarcons',",
#   'dimmakcollection',
#   'dreams",',
#   "earthdayeveryday',",
#   'eclipse2017',
#   "everythingisenergy',",
#   "firstsupper',",
#   "gamelatron',",
#   "goodfencesmakegoodneighbors',",
#   'goodnightsweetheart',
#   "goodnightsweetheart',",
#   "gothamcity',",
#   "greenfingers',",
#   "happinesseverywhere',",
#   "herecomestherainagain',",
#   "homesweethome',",
#   "ilovenewyork',",
#   "imissparis',",
#   "iseeaheart',",
#   "iwishiwasthere',",
#   'janezic",',
#   'jeffkoons',
#   "jenga',",
#   "katharinagrosse',",
#   "lestyleàlafrançaise',",
#   'liketkit',
#   'loveafterlove",',
#   "lovealwayswins',",
#   'matilijapoppy',
#   "medicine',",
#   "missyoualreadysummer',",
#   'mytinyatlas",',
#   "mytinyatlas',",
#   "neverforget',",
#   "newfriend',",
#   'nightblooms",',
#   'paarepons",',
#   "rainorshine',",
#   'reikawakubo',
#   'secretgarden',
#   'selfcare',
#   'serenitynow',
#   'steveaoki",',
#   "summerdontgo',",
#   'swingoutsister',
#   'tbt',
#   "tbt',",
#   'totaleclipseoftheheart",',
#   "vermeer',",
#   'wmw',
#   "womenrule',",
#   'womensmarchworldwide",',
#   "wonderwheel',"},
#  {'',
#   '17ansdamitié",',
#   "19hlabonneheurepourlaplage',",
#   "40ansdemariage',",
#   '40ansdemariagedemesparents',
#   '5ans",',
#   '5ansdamitié',
#   '9mois',
#   'Aubervilliers',
#   'César',
#   'Flair',
#   'Flair.',
#   "Flairfaitdespetits',",
#   'France5',
#   'France5.',
#   'Green',
#   'Martine',
#   'Moiaussijebalancesurmoncouple',
#   'Nice',
#   'Silencecapousse',
#   'adresseparisienne",',
#   'aigledor',
#   'amazingolga",',
#   'amien',
#   "amiens',",
#   'aquiletour",',
#   'ardeche",',
#   'arreterletemps',
#   'artisanat',
#   'automniscoming',
#   'auxurnescitoyens',
#   'baby',
#   "babyoutfit',",
#   'backtocreche',
#   'baguebeaute',
#   'baraquedelocinstagramable",',
#   'beagle',
#   'beauties',
#   'beauty',
#   'bebe',
#   "behappluie',",
#   'belleinitiative',
#   'berbère',
#   'bffandkids',
#   'biberons",',
#   'biberonsaemboiter',
#   'biberonsempilables',
#   'bijou',
#   'bijoux',
#   'bio',
#   'birthday',
#   'bodyachaqueanniv',
#   'bodyleresultat',
#   'bois',
#   'bonnenuitlesmamansdebordees",',
#   'bonplan',
#   'booohhhhh',
#   'bossunotredame',
#   'bougie',
#   'boulogne',
#   'bouquet.',
#   'boxenfant',
#   'bravoelsa',
#   'broderie',
#   'brunchà2',
#   'buddhabowl',
#   'bugaboo',
#   'bujo',
#   'bulletjournal.',
#   'byebyeangers',
#   'cachemireaddiction',
#   'cactus',
#   'cactus",',
#   'cadeaumaitresse",',
#   'cafedumatin',
#   'canada',
#   'cancer',
#   'cancer.',
#   'cape',
#   'carnage',
#   'carnaval',
#   'carrotcake',
#   'catseyes',
#   'ccp2017",',
#   'celanenousregardepas',
#   "cenestpasmatenuedejardinage',",
#   'ceramique',
#   'ceramique",',
#   "cestpartipourunejourneeremplie',",
#   'ch4v',
#   'chanceuse',
#   'chasseautresor',
#   'chaton',
#   'chaussettes.',
#   'chaussures',
#   'chevaliers',
#   'chocolat',
#   'chocolats',
#   'choupinettes',
#   'coiffuredelete',
#   'coiffuredujour',
#   "collab',",
#   'concentration',
#   'copainspourlavie",',
#   "copainspourlavie.',",
#   'copinedematernellemodeuse',
#   'corailvsrouge',
#   'costarica',
#   'costarica??',
#   'cotentin.',
#   "coucoumaman',",
#   'country',
#   'couronnedefleurs',
#   'cousinforever',
#   "cousinforever',",
#   'cousinsparty',
#   'cousinstime",',
#   'couture',
#   "couture',",
#   'createur',
#   "createurs',",
#   'creatifdays",',
#   'creation',
#   'creation",',
#   "creatrice',",
#   'creatricedetalent",',
#   'creatricesdetalent',
#   'crochet',
#   'créateurs',
#   "cuisineayurvedique',",
#   'dailydoseoffiesta',
#   'dailydoseoffiesta",',
#   'deboutçachangetout',
#   'declarationdamitiepourSeverine',
#   'declarationdamourpourtitlee',
#   'deco',
#   'demaintournage=ravalementtotal',
#   "dequoiseduireferdinand',",
#   'despacito',
#   "diabete',",
#   'dimanchematin",',
#   "dismoioui',",
#   'diy',
#   "diy',",
#   'diy.',
#   "dormir3h',",
#   'douelafontaine',
#   'dragons',
#   'eat&swim",',
#   'edgar&Axel',
#   'edgarenmodeblond',
#   'edgarestunrebel',
#   'edgarjardine',
#   'edgarlartiste",',
#   'edgarlevoyou',
#   'edgarmanuel',
#   'edgarmonfils",',
#   'edgarpresent',
#   'ellegirl).',
#   'embroidery',
#   'enceinte",',
#   'enfantcitoyen',
#   'entreaide",',
#   'entrepreneuse",',
#   'epiceriemousseline',
#   'etde2',
#   'ete2017',
#   'etlesautres',
#   'fab&me',
#   'faireuneheureuse",',
#   'famille',
#   'fandecanopea',
#   'fandutravaildariane',
#   'fetedelecole',
#   'feteduprintemps",',
#   'fillon',
#   'flair',
#   'fleursenpapier',
#   'florenceadutalent",',
#   'flower',
#   'flowerpower',
#   "flowerpower',",
#   'flowers',
#   'flowerspower',
#   'food',
#   'foreverpetitlutin',
#   'france5',
#   'france5",',
#   'français',
#   'frenchcreator',
#   'frenchfashion',
#   'fringuedemaman",',
#   'fun',
#   'furoshiki',
#   'gaitemontparnasse',
#   "galeredecheveux',",
#   'garden',
#   'gaspardBG',
#   'gateau',
#   'gentillesse',
#   'gestesquisauvent',
#   'girl',
#   'girls',
#   'girlsbeauty',
#   "girlsontv',",
#   'goldorsilver',
#   'greece',
#   'greekfood',
#   'green',
#   "green',",
#   'greengirl',
#   'grilledete',
#   'grosseconfession',
#   'grossesjoues",',
#   "halloweencollectif',",
#   'hamon',
#   'handspinner',
#   'happyavec@mumdaymornings",',
#   'hb",',
#   "help',",
#   'himmeli',
#   "horse',",
#   "hortillonages',",
#   'i?lescreatrices",',
#   "ideeweekend',",
#   'idpresentationcafe",',
#   'igc',
#   'igcbas',
#   'igersamiens',
#   'ilestfort',
#   'iloveplaytime',
#   'imaginationedgar',
#   'indien',
#   'indiendederniereminute',
#   'insectes',
#   'iphonelover',
#   'jadorelepapier',
#   'jadorelesud",',
#   'jaguar',
#   "jaigaleréàfaireunephotodemoipotable',",
#   'jamaisfroid",',
#   'jamaissansmonfrere.',
#   "jardinbagatelle',",
#   'jecroisentoicharlotte??",',
#   'jenenrevienspas',
#   "jepenseanice',",
#   'jesuisjoieettristesse",',
#   'jesuistropsensible',
#   'jewel',
#   "journalistslife',",
#   "jrigang',",
#   'jumellesdetrousse',
#   'jungle',
#   'kids',
#   'kids",',
#   "kids',",
#   'kidsetc",',
#   "kidsetc',",
#   'kidsingreece",',
#   'klindoeilcarreau',
#   'kobido',
#   'labelleauboisdormant"]',
#   'lachainedescreatrices',
#   'lachainedescreatrices",',
#   "lachainedescreatrices',",
#   'lachainedescreatrices.',
#   'lacreatricedulundi',
#   'lacreatricedulundi",',
#   'lacreatricedulundi.',
#   'lafetedescigales.',
#   'lalistepourmescopines',
#   "lalumiereducotentin',",
#   'laquariumdelarochelle',
#   'lareinerenarde',
#   'lareleve',
#   'larentreeftv',
#   "larentreeftv.',",
#   'larobequibouloche",',
#   'lasiestedumatin',
#   "lastday',",
#   'laurentdelahousse',
#   "laviedebebeestunboomerang',",
#   'laviemechappe",',
#   'lebandeauserafinalementuneecharpe',
#   'lebilan',
#   'lebonnetdechristine',
#   'lecitoyenaucoeurdu',
#   'lecolebuisonniere.',
#   'lecoteobscurdedgar",',
#   'lecoteobscurdusoleil',
#   "lecoteobscurdusoleil',",
#   'lecoteobscurdusoleil.',
#   'lecreateurdulundi",',
#   'ledeguisementpascher',
#   'legranddebat',
#   "lemarronier',",
#   'lesaperostricotdeboulbi',
#   'lescheminsdelarose',
#   'lescoulissesdesilence',
#   'lescreatricessontmesamies',
#   'lescreatricessontmesamies",',
#   'lesenfantscitoyens",',
#   'lesfillesquijardinent',
#   'lesmaternellesforever',
#   'lesmaternellesforever",',
#   'letsgothelma",',
#   'levieilantibes.',
#   'lifestyle',
#   'macollectiondestephanecouronné",',
#   'macron',
#   'madeinfrance',
#   'makers',
#   'maman',
#   'mamanaulit",',
#   'mamanfan',
#   'mamangaga',
#   'mamans',
#   "mamanscreatives',",
#   'mamansenfete.',
#   'mamantoujourstiraillée',
#   'mapremiereproduction",',
#   'meilleurequetinder',
#   'melanchon',
#   'mememonperevalacheter',
#   'merci',
#   'mercialexandra",',
#   "mercialicia',",
#   'merciaurelie',
#   'mercicapucine',
#   'mercicaroline",',
#   'merciclaire',
#   'merciconstance",',
#   'mercietbravomorgane??",',
#   "mercifabfab',",
#   'merciherve',
#   'mercijuliette',
#   'mercilangine',
#   'mercilaquotidienne",',
#   'mercilauren',
#   'mercilescopines',
#   'mercimamie',
#   'mercimanon?',
#   'mercimonfrere',
#   'mercinath",',
#   'mercinathalie',
#   "mercinoemie',",
#   'merciodile',
#   'mercipauline',
#   'mercisabine',
#   'mercisabine",',
#   'mercisanjee',
#   'mercisarah',
#   'mercisuperpauline',
#   'mercivalentine',
#   'mere',
#   'merefan',
#   'miam',
#   'miam",',
#   'michelcymesetmoi',
#   "mignonnerie',",
#   'misterkfightingkit',
#   'mo17',
#   'mo17",',
#   "mo17',",
#   "moijesuiszia',",
#   'momentsaigle',
#   'mompreneurs',
#   'moncampingcarpoursilenceçapousse',
#   'monfrere',
#   "motricitefine',",
#   'mousse',
#   'mum',
#   'mums',
#   'mumstyle',
#   'myjolibag',
#   'mylittleday',
#   'mylittleday",',
#   'myson",',
#   'mystere",',
#   'nails",',
#   "namaste',",
#   'nevergiveup',
#   'newbook',
#   "nicoise',",
#   'niort',
#   'notiseoton',
#   'notreboitedeprod',
#   'notrepremiereprod',
#   'notrepremiereprod",',
#   'notretele.',
#   'nouvellesemainedevacances',
#   'nuitdemeraude',
#   'ogresse",',
#   'oiseaux',
#   'onclepondeurdeBG',
#   'onestbien',
#   "onestmieuxquedevantdesmachines',",
#   "orange',",
#   'organisation',
#   "origami',",
#   'ouiaremakers',
#   'ouicestmoiquifilme',
#   "ouionvoitlemobilesido',",
#   'oursaddicted',
#   "out',",
#   'panier',
#   'papeterie',
#   'papeteriemere&fille',
#   'paques',
#   'parentalité,',
#   'parents",',
#   'parentssolidaires",',
#   'paris',
#   "pasbesoindesnapchat',",
#   'passepoil',
#   "passionplaymo',",
#   "passionstylo',",
#   'passiontutuuuuuuuure',
#   'patch',
#   'patisseries...\\r\\nAlixe',
#   'pays',
#   "perfecthat',",
#   'perfectshoes',
#   "petitappartmaisheureuxdedans',",
#   "petitemain',",
#   'pilate',
#   'pirate',
#   'playtimeparis',
#   'playtimeparis.',
#   'pleindesensations',
#   'pointchainette',
#   "pointdecroix',",
#   'pointmousse',
#   'pompongirl",',
#   'poterie',
#   'pourquoicasserdesvitres",',
#   'pregnancy',
#   "premiereelectionpresidentiellepouredgar',",
#   'premierssecours',
#   'prepadete',
#   'presidentielles',
#   'presse',
#   "presse',",
#   'project",',
#   'pujadas',
#   'puydufou',
#   'puydufou,',
#   "qdtuesmamantunepeuxjamaislire',",
#   'quelaforcesoitavecvous',
#   "reflux',",
#   "reservebonbecsdemain',",
#   'rgo',
#   'robindesboisestdevenuindien',
#   'rocknroll',
#   'sacminute",',
#   'sain',
#   'scapousse',
#   'scapousse",',
#   "scapousse',",
#   'scapousse??',
#   'scenographieedgar',
#   "serresdauteuil',",
#   'shoes",',
#   'sia",',
#   'silencecapousse',
#   'silencecapousse",',
#   'silencecapousse.',
#   'silenceçapousse',
#   'slowparty',
#   'sologne",',
#   "sorrybettyboop',",
#   "sortiescolaire',",
#   'sosiemichelcymes',
#   'soutiendescreatrices',
#   'soutienofficieldescreateurs',
#   'souvenirdenfance',
#   'starswars',
#   'stmarguerite',
#   'stokkeconnection",',
#   'summer2017",',
#   'super4',
#   'supersite",',
#   'surprisepourdemisel',
#   "suspension',",
#   'sweat',
#   'sweatquichange',
#   'taches',
#   'talent',
#   'talent",',
#   'tapis',
#   'tatoo',
#   "teasing',",
#   'thelma',
#   "thelma&suzanne',",
#   'thelmabombasse',
#   'thelmacaline",',
#   'thelmachoupote',
#   'thelmaecrivaine',
#   "thelmahotessedelair',",
#   'thelmalaclasse",',
#   'thelmalafemme',
#   'thelmalincruste',
#   "thelmamiam',",
#   'thelmamonchat",',
#   'thelmaone',
#   'thelmaone",',
#   "thelmaonepartie2',",
#   'thelmaonthebeach',
#   'thelmapotdecolle',
#   "thelmapotdecolle',",
#   'thelmasorssesorteils',
#   'thessaloniki',
#   'thessalonique',
#   'thessaloniqueavecenfants',
#   "thessaloniqueavecenfants',",
#   'tipi',
#   'tissage',
#   'togetherstronger',
#   'togetherstronger",',
#   'totalementnostalgique',
#   'totalementàlabourre',
#   'touspresident',
#   'toutesavecmaud',
#   'toutsurlecafe',
#   'tricot',
#   'tricot",',
#   'uneanneeecoulee',
#   'unejonquillepourcurie.',
#   'unenicoiseaparis",',
#   'unepoupeepourlavie',
#   'unfauteuilpourdeux',
#   'unjobpoursarah',
#   'unnouveaujobpourmargaux',
#   'vegan',
#   "vegetal',",
#   'vendee',
#   "vendeetourisme',",
#   'vestiaireenfant',
#   "vintage',",
#   'vivelafrance',
#   'vivelecodepuk?',
#   'vivelecrochet',
#   'vivelelundi',
#   'vivelescostumes',
#   'vivelescreateurs',
#   'vivelesfautes',
#   "vivelespotes',",
#   'vivelevendredisoir',
#   'voiture',
#   'voiturefull',
#   'weddingdecor',
#   'women',
#   "wonderwoman',",
#   'xjr1994',
#   'yacobsonballet',
#   'yallah',
#   'yoga',
#   'yogistyle",',
#   'youmakemyday'},
#  {"acolorstory',",
#   'charlottesville.',
#   'lasvegas',
#   'linkinbio',
#   'linkinbio",',
#   "linkinbio',",
#   'linkinbio\\r\\n\\r\\nA',
#   'linkinbio\\r\\n\\r\\nAlso,',
#   'linkinbio\\r\\n\\r\\nIf',
#   'metoo',
#   "metoo',",
#   'mydomaineeats',
#   "partner',",
#   'prayersforvegas',
#   "tastingtable',",
#   'thehtirlby',
#   'thethirby',
#   'thethirlby',
#   'thethirlby",',
#   "thethirlby',",
#   "thethirlby']",
#   'thethirlby\\r\\n\\r\\nPLUS',
#   'thethirlby\\r\\n\\r\\nThank',
#   'thethirlby\\r\\n\\r\\nphoto',
#   'thethirlby\\r\\nshot',
#   "thirlbytealattes',",
#   "thirlbythebook',",
#   'tomorrowlist?",',
#   'vegan,'},
#  {'30thanniversary',
#   '5oclocksomewhere',
#   '??100?',
#   "?????',",
#   '??????',
#   'AW2017',
#   'AbsoluteFiller,',
#   'Advanced3DMascaNegra',
#   'AlessandroMichele',
#   'AmagazineCuratedBy',
#   'AnteprimaHK',
#   'ApivitaHK',
#   'AquaVitaLotion',
#   'ArmaniBoxHK',
#   'ArtBasel',
#   'AsiasBestPastryChef',
#   'AudreyHepburn',
#   'AveneHK',
#   'BVLGARI',
#   'Beijinglife',
#   'BestFemaleChef',
#   'BestinBoots',
#   'BibnHops',
#   'CREAMWASH',
#   'CableTV',
#   'CaviarDay',
#   'CharityPot',
#   'Chinesemyth',
#   'ClicquotRich',
#   'Clicquotcrew',
#   'Clicquotpicnic',
#   'CoboHouseHK',
#   'Colette',
#   'CollaborationGroup",',
#   "CollaborationGroup',",
#   'DiamondCleanSmart',
#   'EastImperial',
#   'EauThermaleAvène\\n.\\n@eauthermaleavenehk',
#   'EmbracelifeNiravModi',
#   'EmbracelifeNiravModi\\n.\\n@niravmodijewels',
#   'EnglishOak',
#   'FW2017',
#   'FantasticTV',
#   'FeedingHK',
#   'FendiHK',
#   'FiftyShadesDarker',
#   'FirstClassBeauty',
#   "FlareCommunications',",
#   'FoolsandMagicians',
#   'FourFoxSake',
#   'Friday',
#   'GigiHadid',
#   'GongHeiFatChoi',
#   'GoodDayToSmile',
#   'GoodFriday',
#   'Gucci',
#   'Gyoza',
#   'HOcheesy',
#   'HappyMooncakeFestival',
#   "HarpersBazaarcontributor',",
#   'HermesHK',
#   'HermesHomme',
#   'ILCIOCCOLATO',
#   'Influencer',
#   'ItalianStandardWirebag',
#   'JMLPacificPlace',
#   'JaniceWong',
#   'Japanese',
#   'JoMalone',
#   'JoMaloneLondonHK',
#   'JustBecauseHK',
#   'KenGrier',
#   'KerryDiningbyDesign',
#   'KirRoyal',
#   'Kuba',
#   'LCxStuartWeitzman',
#   'LaPrairie',
#   'LaPrairieHK',
#   'LancômeHK',
#   'LipsCafe',
#   'LipsCafeHK',
#   'LucBelaire',
#   'MCMCAFE',
#   'MCMINSPIRE',
#   'MCMworld',
#   'MDNAskinHK',
#   'MHDHK",',
#   'MacallanHK',
#   'MagneticBooster,',
#   'MagneticKit',
#   'MajeHK',
#   'March8th',
#   'MasterofPhotography',
#   'MichellinStar',
#   'Monday',
#   'Monday!',
#   'MyArmaniCushion',
#   'MyArmaniToGo',
#   'Nespresso?\\nMixologist',
#   'NespressoHK',
#   'NiravModi',
#   'OnlyTheEssentials',
#   'Oreo',
#   'Pagodalife',
#   'Paris',
#   'Paris!\\n.\\n#healthylifestyle',
#   'Paris??',
#   'Paris??\\n.\\n#tapfordetails',
#   'Paris??\\n.\\n@intimissimiofficial',
#   'Paris??\\nGo',
#   'ParisJetaime',
#   'Parisienne',
#   'Peoplefootwear',
#   'Peruvian',
#   'PetraCollins',
#   "PetraCollins's",
#   'PhilipsHK',
#   'PoemPatisserieByTate',
#   'PorterHouse',
#   'RLFall2017',
#   'RNApower',
#   'RafSimons\\n.\\n#Kvadrat',
#   'RalphLaurenFW17]\\n.\\n@ralphlauren',
#   'ReFaCLEAR',
#   'RedListAwards2017',
#   'RedListAwards2017!',
#   'RedbullLABBAR\\n.\\n@downtowncocktails_hk',
#   'Rooster',
#   'RunForGirlsRight',
#   'RunForGirlsRights',
#   'RunwayHK',
#   'SKIIHK',
#   'SL78',
#   'SeaLavenderMask',
#   'September2017collection',
#   'Sonicare',
#   'StevenKlein',
#   'Sunday\\n.\\n#strollingaround',
#   'SushiLoveHK',
#   'TGalleriaBeauty',
#   'TGalleriaBeautyXHABITU',
#   "THESWANKERinPARIS',",
#   'THESWANKERinParis',
#   'THESWANKERinParis",',
#   "THESWANKERinParis',",
#   'TaiKooLi',
#   'TheArtOfCaviar',
#   'TheBarAwards2017',
#   'TheMacallan',
#   'TheParisGuru',
#   'TheSerum',
#   'TimeCapturedLive',
#   "TimeCapturedLive',",
#   'UDhongkong',
#   'Valentines2017',
#   'ValentinesDay',
#   'ValentinesDay!\\n\\nJust',
#   'Vday',
#   'VickyLau',
#   'Wireart',
#   'WomensDay',
#   'aboutalook',
#   "aboutalook',",
#   'accessoriescollection',
#   'activatedcharcoal',
#   'actresslife',
#   'adventures',
#   'advocadolover',
#   'aftermath',
#   'afternoonvibes',
#   'amagazinecuratedby',
#   'aromatique",',
#   'artbasel',
#   'artbasel",',
#   'artbaselhk',
#   'artcentral',
#   'artinspiration',
#   'artinstallation',
#   'artisanchocolate',
#   'artofjewelry',
#   "artofjewelry',",
#   'artofpatisserie',
#   'artwork',
#   'atheleisure',
#   'autumnwalks',
#   'avocadoaddict',
#   'bagonbag',
#   'bagsnob',
#   'bagstagram',
#   'barscene',
#   'beautifulmatters',
#   'beautifulmatters",',
#   "beautifulmatters',",
#   'beautifulthings',
#   "beautifulthings',",
#   'beautifulworld',
#   'beautyawards',
#   'beautycampaign',
#   'beautycare',
#   'beautycommunity',
#   'beautyguru',
#   'beautyjunkie',
#   'beautyjunkies',
#   'beautyjunkies",',
#   'beautyproducts',
#   'beautyroutine',
#   "beautyroutine',",
#   'beefroast',
#   'beforebed',
#   'bestiegoals',
#   'bestkeptsecret...',
#   'bestofthebest',
#   'birthdayfun',
#   'birthdayparty',
#   'birthdaysurprise',
#   'blackbottlegirls',
#   'blazer',
#   'boosting',
#   'boulanger',
#   'boulongerie',
#   'brainbehindthebrand',
#   'brunchgoals',
#   'brunchideas',
#   'bunniesofinstagram',
#   'burgergram',
#   'buy1get1free',
#   'buzzfeast',
#   'cafeculture',
#   'cafetería',
#   'cashmere',
#   'catchmeifyoucan",',
#   'caviar',
#   'celebration',
#   'champagnecampaign',
#   'champagnetime',
#   'champgnepairing',
#   'changedestiny',
#   'charismatic',
#   'charityrun',
#   'cheatdayeats',
#   'cheers',
#   'chefAlvinLeung',
#   'chic',
#   'chillax',
#   'chillingout',
#   'chocolatier',
#   'classics',
#   'cocktailgram',
#   'cocktailmaker',
#   'cocktails',
#   'cocktailsofinstagram',
#   'cocktailstime',
#   'coffee',
#   'coffeetime',
#   "coffeetime',",
#   'comfortfood',
#   'comfyclothes',
#   "comfystyle',",
#   'concretejungle',
#   'cookies',
#   'coolingdown',
#   'coolingoff',
#   'cosmomovie',
#   'craziness',
#   'createyourowntwist',
#   'crewpower",',
#   'cuisineart',
#   'cuisinecaptures',
#   'cuisinehealthy",',
#   'curator',
#   'currentlywearing',
#   'currentmood',
#   'custommade',
#   'dailyartpiece',
#   'dailydoseofbeauty',
#   'dailyessentials",',
#   'dailyfoodfeed",',
#   "dailymotivation',",
#   'decorativeart',
#   'deluxe',
#   'denimday',
#   'denimjeans",',
#   "denimstyle',",
#   'designinspiration',
#   'dessertstagram',
#   'desserttable',
#   'detoxifying',
#   'dilemma,',
#   'diningcrisis',
#   'dininginhk',
#   'diptyquehk',
#   'discoverhongkong',
#   'discoverhongkong",',
#   'djworld',
#   'doorcrashing',
#   'doseofcolors',
#   'downtowncocktails2017',
#   'dreamcometrue',
#   'dressupdaily',
#   'drinkies',
#   'drinkspecial',
#   'drinkwithview',
#   'easybreezy',
#   'eatcleangetlean',
#   'eatgreen',
#   'eatingfortheinsta',
#   "eatinggood',",
#   'eatwithme',
#   'eatwithme",',
#   'ecofriendly',
#   'effortless',
#   'elegance',
#   "elevatesciencetoart',",
#   "embroideryart',",
#   'enchanting',
#   'espressomartini',
#   'eveningdress',
#   'exploreeverything',
#   'eyecandies.',
#   'eyeserum',
#   'fabriccraft',
#   "facepalmmoment',",
#   'facialtreatment",',
#   'failure',
#   'fashion',
#   'fashionart',
#   'fashionbloggerstyle',
#   'fashionbloggerstyle",',
#   'fashionbombdaily',
#   'fashiondairies',
#   'fashiondiaries',
#   'fashiongirl',
#   'fashionistastyle',
#   'fashionmuse',
#   'fashionpajamas',
#   'fashionpreview',
#   'fashionrules',
#   'fashionsportswear',
#   'fearless',
#   'feelingbeautiful',
#   "feelingsexy',",
#   'female',
#   'feminism',
#   'femmefatale',
#   'femmetravel',
#   "femmetravel',",
#   'festivalready",',
#   'finedining',
#   'fisforfendi',
#   'fisforfendi\\n.\\n#throwbackthursday',
#   "fitnesswear',",
#   'flashesofdelight',
#   'flatlaystyle',
#   'flipflops',
#   'floralfix',
#   'foodart',
#   'foodcoma',
#   'foodfix',
#   'foodiefix',
#   'foodieflatlays',
#   'foodieforlife',
#   'foodieforlife",',
#   "foodieforlife',",
#   'foodiegirl',
#   'foodiegram',
#   'foodiehub",',
#   'foodielife',
#   "foodiesdiary',",
#   'foodiesofinstagram',
#   'foodinparis',
#   'foodmatters',
#   'foodtasting',
#   'foragoodcause',
#   'fortunecookie',
#   'freaks',
#   'frenchie',
#   'fridayvibes',
#   'fridayvibes",',
#   'friendstime',
#   'fusionfood',
#   'futurehome',
#   'gelato',
#   'getinmybelly',
#   'gifting',
#   'giftoflove',
#   'gintonic\\n.\\n#GinJubilee2017',
#   'girlgoneinternational',
#   'girlschat',
#   'girlsnightout',
#   'girlspower',
#   'giveaway',
#   'glamglowhk',
#   'globaltravelgram',
#   'glowinthedark',
#   'gold',
#   'goodday',
#   "goodday',",
#   'goodeats',
#   'goodeats",',
#   "goodeats',",
#   'goodfood',
#   'goodlifefitness',
#   "goodlifefitness',",
#   'goodmoments',
#   'goodnight',
#   "goodvibes',",
#   'grandopening',
#   "greatvibe',",
#   'greenliving',
#   'greens',
#   'handcrafted',
#   "handcrafted',",
#   'handinframe',
#   'handsinframe',
#   'happeningnow',
#   "happeningnow',",
#   'happinessiskey',
#   'hautdiamantaire',
#   'healthyeats',
#   'healthylifestyle',
#   'healthyrecipes',
#   'heartymeal',
#   'highmoments',
#   'hkartweek',
#   'hkevent',
#   "hkevent',",
#   "hkfoodsnap',",
#   'homeawayfromhome',
#   'homecook',
#   'homecooking',
#   'homedecor',
#   'homemade',
#   'hongkongartweek',
#   "hongkongartweek',",
#   'hospitality',
#   'hotpot',
#   'hotsauce',
#   'hourglass',
#   "huffposttaste',",
#   'hysanplace',
#   'iconic',
#   'ilcioccolato',
#   'iloveyoumom',
#   'incomfort',
#   'indiandesigns',
#   'innovationandyou',
#   'inourshoes',
#   'inspiredbymixology',
#   'inspo",',
#   'inspocafe',
#   "inspogram',",
#   'instagramstories',
#   'installationart',
#   "interiorinspo',",
#   'internationaldelight',
#   "itsabeautifulday',",
#   'justbecause',
#   'justbecausehk',
#   'kerrydiningbydesign',
#   'kidatheart',
#   'kissylips',
#   'koreanfusion',
#   'ladyinred',
#   'laprairiehk',
#   'lavender',
#   'leathergoods',
#   "letscatchupovercoffee',",
#   'letssupporttogether',
#   'lifebalance',
#   'lifegoeson',
#   'lifestyleblogger',
#   "lifestyleblogger',",
#   'lifestylechoice',
#   'lifestylechoice",',
#   "lifestylechoice',",
#   'lifestylechoices',
#   'lifestylechoices",',
#   "lifestylechoices',",
#   'lifestylegoals',
#   "lifestylegoals',",
#   'lifewelltraveled',
#   'likeneverbefore',
#   'limitededition',
#   'lingeriefashion',
#   'lipcolor',
#   'lipstick',
#   'lipstickismyvice',
#   'lipstickjunkie',
#   "lipstickjunkie',",
#   'liveinthemoment',
#   "liveinthemoment',",
#   'livingthegoodlife',
#   'livingthegoodlife",',
#   "livingthegoodlife',",
#   'lobster',
#   'lookatme',
#   'lookbook',
#   'lookbook",',
#   'lookgoodfeelgood',
#   'lookinggood',
#   'love',
#   'loveandhate',
#   'loveit',
#   'loveit",',
#   'loveyourselfmore',
#   'loveyourskin',
#   "loveyourskin',",
#   'luxuryart',
#   'm?rrorselfie',
#   'madeinNormandy',
#   'madonnastyle',
#   'maffia',
#   'makeithappen',
#   'makeitright',
#   'makeup',
#   'makeupinspo',
#   'makeupjunkie',
#   'makeupjunkies',
#   'makeupobsessed',
#   'masterofphotography',
#   'mattlipsobsession',
#   'mediaxmumm',
#   'medicalproven',
#   'menupsidedown',
#   'metime',
#   'midcut',
#   'midnightblue',
#   'mindovermatter',
#   'minimalism",',
#   'minimalistic',
#   'minimalobsession',
#   'mirrorselfie',
#   'mixandmatch',
#   'mixology',
#   'moderncuisine',
#   'momentsofmine',
#   'momentsofmine",',
#   "momentsofmine',",
#   'mondaymotivation',
#   'mondaypromotion',
#   'mondaysbelike',
#   'moodboard:',
#   'moodyportraits',
#   'moreroomoflive',
#   'mothersday',
#   'mules',
#   'muse',
#   'musicislife',
#   "musicislife',",
#   'mydiptyquehour',
#   'nakedpalette',
#   'natural',
#   'neon',
#   'newincloset',
#   'newintown',
#   'newshades',
#   'nightout',
#   'noblewood',
#   'nostressisthebest',
#   'notetoself',
#   'nothingisordinary',
#   'nottobemissed',
#   'nourishing',
#   'om',
#   'omakase',
#   'onlyheessentials',
#   'onlytheessentials',
#   'onthebed',
#   'onthetable',
#   "onthetable',",
#   "ootd',",
#   'oralhealth',
#   'outfit,',
#   'outfitgoals',
#   'outfitinspiration',
#   'outfitshare',
#   'packingtips',
#   'paperart',
#   'papercraft',
#   'paperflowers',
#   'parisfoodguide',
#   'parisienne',
#   'parisjetaime',
#   'partyideas',
#   'partyparty',
#   'pastelpurple',
#   'patternart',
#   'pattiserie',
#   'peoplefootwear',
#   'perfectmoist',
#   'perfumecollection',
#   'petlove',
#   'photocampaign',
#   'photogenic',
#   'pinkisthenewblack\\n.\\n#tapfortags',
#   'piñata',
#   'platingart',
#   'poolside',
#   'popup',
#   'portrait_ig',
#   "portraitcollective',",
#   'portraitphotography',
#   'portraitsmag',
#   'poseforthecamera',
#   "poseforthecamera',",
#   'poseingforthecamera',
#   'poser',
#   'positivevibes',
#   'premiumfabricsfororder",',
#   "prestigious',",
#   'preview',
#   'primeasiapr',
#   'primeasiapr",',
#   "primeasiapr',",
#   'princessdiaries',
#   "putyourhandsup',",
#   'ramen',
#   'red',
#   'redbullcocktail',
#   'retro',
#   'roofterrace',
#   'rooftopvibes',
#   'sakedessert',
#   'saladrecepies',
#   'samesamebutdifferent',
#   'satisfying',
#   'saturdaymood',
#   "saturdaymood',",
#   'savorthemoments',
#   'scentsational',
#   'scentsational",',
#   "sculptureart',",
#   'selfiemode',
#   'sensitiveskinsolution',
#   'sharelove',
#   'sharewithlove',
#   'sharingiscaring',
#   'shoptherunway',
#   'shotoniphone7plus',
#   'shoutout',
#   'silk',
#   'simpleandclean',
#   'skincareroutine',
#   'skincavia',
#   'skincaviar',
#   'slavetomakeup',
#   'slouchy',
#   'softcream',
#   'softshell',
#   'softy',
#   'someonespecial',
#   'soulfood',
#   'southerncooking',
#   'sparklingdrinks',
#   'specialmenu',
#   "specialmenu',",
#   'specialone',
#   'specialscreening',
#   'spicyfood',
#   'spoiledlife',
#   'sportgoals',
#   'sportsbra',
#   'sportsfashion',
#   'sportsstyle',
#   'springsummer2017',
#   'springtime',
#   'standupandspeakup',
#   'stateofmind',
#   'streetsnap',
#   "streetsnap',",
#   'strikeapose",',
#   'styleblogger',
#   'stylechallenge',
#   'stylechoice',
#   'stylechoice",',
#   "stylechoice',",
#   'stylecollective',
#   'stylecollective",',
#   "stylecollective',",
#   'stylediaries',
#   'stylediary',
#   "stylediary',",
#   'stylefix',
#   'styleinspo',
#   'styleiswhat',
#   "styleiswhat',",
#   "stylenotes',",
#   "stylingtips',",
#   'stylish',
#   'suitup',
#   'summer',
#   'summeressentials',
#   'summermood',
#   'summertreats',
#   'sunken',
#   'superyacht',
#   'sustainability',
#   'sweetdelights',
#   "sweetdelights',",
#   'sweetescape',
#   "sweetmoment',",
#   'sweetpea',
#   'sweettreats',
#   'sëduccíon',
#   'tablesituation',
#   'takeabreak',
#   'takeyourtime',
#   'tapfordetails',
#   'tapfordetails",',
#   "tapfordetails',",
#   'tapfortags',
#   'tartan',
#   'tastessogood',
#   'tastingtable',
#   'tequilatime',
#   'textileart',
#   'textureobsession',
#   'theartofcaviar',
#   'theartofcaviar.',
#   'theartofcaviar\\nCome',
#   'thebestever',
#   'thelifestylecollective',
#   'themed',
#   'theparisguru',
#   'thinkpositive',
#   'throwback',
#   'throwbackfriday',
#   "thursdayfunday',",
#   'timekeeper',
#   "timekeeper',",
#   'timeless',
#   'timelessbeauty',
#   'tomato',
#   'topcitybiteshk',
#   'topeats',
#   'toprestaurant',
#   'toprestauranthk',
#   'travelersnotebook',
#   'travellingwith',
#   'traveloutfit',
#   "traveltheworld',",
#   'treatyoself',
#   'treatyourself',
#   'treatyourskinright',
#   'trending',
#   "trending',",
#   'truetoself",',
#   'unicorn',
#   'unicornpower",',
#   'upcoming',
#   'upsidedown',
#   'urbandecayhk',
#   'veggiegarden',
#   'velvet',
#   'vernissage',
#   'veuvecliquotrich',
#   'victoriaharbour',
#   'vietnamesefood',
#   'visionaryart',
#   'visualharmony',
#   'vm',
#   'vocationmode',
#   'walkinginthewoods',
#   'walkinstyle',
#   'wanderfolk',
#   'wanderluster',
#   "wearehongkongers',",
#   'weathergotmelike',
#   'weekend...?\\n.\\n#abouttheweekend',
#   'weekendstyle',
#   'weekendvibes',
#   'weekendvibes!\\n.\\n#5oclocksomewhere',
#   "weekendvibes',",
#   'whatiwore',
#   "whatsonmenutoday',",
#   'whatyouwearing',
#   'wheresmysunshine',
#   'whiskytime',
#   "whiskytime',",
#   'whiteisright',
#   'wirebag',
#   'womenentrepreneurs',
#   'womensday',
#   'workofart',
#   'workout',
#   'workvacation',
#   'worldfriendly",',
#   'yogainspiration',
#   "youdeservethebest',",
#   'yuma',
#   'zen',
#   'zen,',
#   'zeropreservatives'},
#  {'2',
#   'BringBackTheClassics',
#   'CNY',
#   'FrenchWeek,',
#   'LebaneseWeek',
#   'RUOK",',
#   'RUOK.',
#   'SpanishWeek',
#   'TVWeekLogies',
#   'TheChefsLine',
#   'TheChefsLine!',
#   'TheChefsLine!!',
#   'TheChefsLine,',
#   'TheChefsLine.',
#   'TheChefsLine...',
#   'TheChefsLine....',
#   'TheChefsLine:',
#   'TheChefsLine?',
#   'TheTruth',
#   "VegasAUS',",
#   'VegasUncorkd',
#   'abcradio',
#   'aliencovenant',
#   'aussiebeef',
#   'aussietalent',
#   'bastilleday',
#   'bathtuboffice',
#   'becausewereworthit',
#   'beefrendang',
#   'beignets',
#   "bellafreud',",
#   'bluetonkinese",',
#   'bonappetitmag',
#   'boomskakalaka',
#   'breadislife',
#   "brianjonestownmassacre',",
#   'bringbacktheclassics',
#   "brunchbooze',",
#   'businesschicks',
#   'butwhere',
#   "caffeineIV',",
#   'cake',
#   'cake",',
#   'cakeforbreakfast',
#   "california',",
#   'camparioclock',
#   "changethedate',",
#   "charlotteolympia',",
#   'chocolate',
#   'cny',
#   "cny',",
#   'dairyfree',
#   "dairyfree',",
#   'dead',
#   "dionmimi',",
#   "dontmesswithagirlwhocanshoot',",
#   'edibleweeds",',
#   'f52grams',
#   "f52grams',",
#   'feedfeed',
#   'feedfeed",',
#   "feedfeed',",
#   'fiesta',
#   'fooderati",',
#   "fooderati',",
#   'foodiefriday',
#   'foodnetwork",',
#   'foodprep",',
#   'foodstyling',
#   "foodstyling',",
#   "freshas',",
#   'friedrice',
#   'glutenfree',
#   'gojima',
#   'goldcoastfood",',
#   'gotanyblacker',
#   "gotanyblacker',",
#   "greekweek',",
#   'gulabjamun',
#   'hainanese',
#   'healthybreakfast',
#   'healthyfood',
#   "holycroque',",
#   'howdoyoutipple?',
#   "imamodelidiot',",
#   'instafood',
#   'instafood",',
#   'integratron',
#   'israeli',
#   'italodisco",',
#   'jetaimejane",',
#   'joshuatree',
#   'joshuatree",',
#   "joshuatree',",
#   'keepingupwiththejoneses",',
#   "keepingupwiththejoneses',",
#   'kiyomigc!',
#   'landers',
#   "lastpush',",
#   'lasvegas',
#   "legseleven',",
#   "leopardforlife',",
#   'logies2017',
#   'logies2017,',
#   'luckyseven',
#   'makeitdelicious',
#   'makeitdelicious",',
#   "makeitdelicious',",
#   "mamamia',",
#   'markolive',
#   'marriageequality',
#   'meatlessmonday",',
#   "melbournefood',",
#   'mexico',
#   'naturalbeauty',
#   'nettle',
#   "neworleans',",
#   "notsponsored',",
#   'onassignment',
#   "onassignment',",
#   'pita',
#   'pizza',
#   "platdujour',",
#   'poolside',
#   'porchetta',
#   'probablynot',
#   'produceawards',
#   'produceawards.',
#   'qtlife',
#   'robelife',
#   "robelife',",
#   "rollas',",
#   "salumi',",
#   'sbsaustralia',
#   'sbsaustralia",',
#   'sbsfood',
#   'sbsfood",',
#   "sbsfood',",
#   'sbstv',
#   "sbstv',",
#   'sojuicy',
#   "sorryforwhatisaidwheniwashangry',",
#   'studio10",',
#   "studiolife',",
#   'suicideprevention',
#   'theblackolive',
#   'theblackolive.',
#   'thechefsline',
#   'thechefsline!',
#   'thechefsline...',
#   'timetosleep',
#   'vegasAUS',
#   'vegasAUS",',
#   "vegasAUS',",
#   'vegasuncorkd',
#   "vegasuncorkd',",
#   'vietnamesefood',
#   'visitvictoria",',
#   'vivalasvegas',
#   "vivalasvegas',",
#   'voteYES',
#   'wastenot',
#   'weddinginspo',
#   'wheatfree'},
#  {'GooglePixel2',
#   'NTAustralia',
#   "NTAustralia',",
#   'TourismTopEnd',
#   'TourismTopEnd",',
#   "TourismTopEnd',",
#   "animatededitseries',",
#   "emojisinthewild',",
#   'giftsfromgoogle',
#   "happyaustraliaday',",
#   "happybirthdaytome',",
#   'iLoveNSW',
#   "iLoveNSW',",
#   'jucyimnsw',
#   "jucyimnsw',",
#   'jucyworld",',
#   "jucyworld',",
#   'katherinegorge',
#   "longlostimagesfound',",
#   'mindilmarket',
#   'newyorknewyork',
#   'newyorknewyork",',
#   "teampixel',",
#   'theyearthat",',
#   "theyearthat',",
#   'toohot',
#   "tourismtopend',",
#   'wangifalls.'},
#  {'einigeszutun',
#   'kokorikids',
#   'mansurgavriel',
#   'schwarzseebeikitzbühel',
#   'gutenmorgen',
#   'urlaubmitkindern',
#   "sonntaginwien',",
#   'winwinwin',
#   'kaiserweltscheffau',
#   'beachbag',
#   'selbermachen',
#   'girlsshouldsupportgirls',
#   "sovielspass',",
#   'baobabcandle',
#   'irojacket',
#   'rausfallschutz\\n.\\n.\\n.\\n.\\n#mamablogger',
#   'canyoning',
#   'playademuro',
#   'ferienende',
#   'momlife\\n.\\n.\\n.\\n.\\n#mamablog',
#   'todayatthebeach',
#   'diefarben',
#   'lieblingsjacke',
#   "münchenmitkindern',",
#   'momblog',
#   'somuchredness',
#   'jeweltones',
#   "fcvie',",
#   'mylove',
#   'naturhotel',
#   'heutefrühbeimgemüsestand',
#   'familyday',
#   "taufe',",
#   'meinekinder',
#   'fashionformoms',
#   'wegmitdendickenjacken',
#   'hemnesbed',
#   'conceptstore',
#   'mallorca\\n.\\n.\\n.\\n.\\n#momblog',
#   'lolasbday',
#   'visitaustria',
#   'daumendrücken\\n.\\n.\\n.\\n#mamablog',
#   'reinventmemories',
#   'motheranddaugther',
#   "valeriesroom',",
#   "thoughts',",
#   'obst',
#   "igersvienna',",
#   'ballongirlande',
#   'nespresso',
#   'skincare',
#   'amhafen',
#   'morningroutine',
#   'intheboysroom\\n.\\n.\\n.\\n.\\n#mamablog',
#   'pressereise',
#   "schönenabend',",
#   'bonton',
#   'meerjungfrauentorte',
#   'regenbogen',
#   'mylittleponylove',
#   'kosmetik',
#   'grossemaus',
#   'mommyanddaughter',
#   'travel',
#   'sundaystyle',
#   'accessoires',
#   'livingwithkids',
#   'summer",',
#   'urtekram',
#   'meerjungfrauengeburtstag',
#   "happyweekend',",
#   'hohesalve',
#   'atthebeach',
#   'latergram\\n.\\n.\\n.\\n.\\n#mamablog',
#   'palmaisworthavisit',
#   'meinefarben\\n.\\n.\\n.\\n.\\n#mamablog',
#   'summerdress',
#   'lunch',
#   'accessoiresforgirls',
#   'ilovefhg',
#   'jetztnetflixundcouch\\n.\\n.\\n.\\n#mamablog',
#   'moreismore\\n.\\n.\\n.\\n#geburtstag',
#   'sommerfrische',
#   'goodmornIng',
#   'minaundlola\\n.\\n.\\n.\\n.\\n#shopopening',
#   "achsomeinsohn',",
#   "familyhotel',",
#   'bellevuejesolo',
#   'urlaubinitalien',
#   'geburtstagsgeschenke',
#   'workshop',
#   'granfoliesbeachclub',
#   'jetztmussichpacken',
#   'birthdaycake',
#   'KinderzimmerChallenge',
#   'happytimeswiththefamily\\n.\\n.\\n.\\n#mamablog',
#   'holidaysinaustria",',
#   'indiefalscheklimazonegeboren\\n.\\n.\\n.\\n.\\n#mamablog',
#   'heutewirdschonwiedergepackt',
#   'pillow',
#   "blogger_at',",
#   'zuckerfrei',
#   'valerieträgt\\n.\\n.\\n.\\n.\\n#mamablog',
#   'inthemountains',
#   'mompreneur',
#   "mfgoesmünchen',",
#   'fermlivingkids',
#   'lebenmitkindern',
#   'meinmädchen',
#   'diefälltschonnichtraus',
#   'bobochoses',
#   'bloggermom',
#   'fashionforwomen',
#   'amstrand',
#   'tortendekoration',
#   'sundaymorning',
#   "happysundaytoyou',",
#   'sommerfarben',
#   'hohessalve',
#   'pinkelephant',
#   'bestdad\\n.\\n.\\n.\\n.\\n#momlife',
#   'sonnenhut',
#   'icecream',
#   'followfriday',
#   "derfrühlingistda',",
#   'mothersfinestblog",',
#   'dieblumenwieseamkleid',
#   'holidaysinaustria',
#   'abjetztgilts\\n.\\n.\\n.\\n#mamablog',
#   'austrianblog",',
#   'jaeh',
#   'makingmemories',
#   'summeroutfitideas',
#   'lanadelrey',
#   'holidaysinitaly',
#   'holidaysinmallorca",',
#   'bellerose',
#   'murobeach\\n.\\n.\\n.\\n.\\n#mamablog',
#   "fashionforgirls',",
#   'sommerferien2017',
#   'stylemom',
#   'mamatochterschmuck',
#   'ikeakinderküche',
#   'ferienintirol',
#   'andratx',
#   'gingham',
#   'greatlittletrading',
#   'kindergeburtstag',
#   'juviacollection',
#   'lifeatthebeach',
#   'mamamode',
#   'soonfour',
#   'shelfie',
#   'beschäftigung',
#   '25hourshotelwien',
#   'meinebuben',
#   'flipflops',
#   'klassiker',
#   'spar',
#   'springisintheair',
#   'charleshotel',
#   'looks',
#   'palmademallorca',
#   'ferieninösterreich\\n.\\n.\\n.\\n#mamablog',
#   'print',
#   'mycrew\\n.\\n.\\n.\\n.\\n#mamablog',
#   'beingamom',
#   'meinmädchen\\n.\\n.\\n.\\n.\\n#mamablog',
#   'einewochevergehtimflug\\n.\\n.\\n.\\n.\\n#mamablog',
#   'blogger_at",',
#   'sunnydaysinthemountains\\n.\\n.\\n.\\n#mamablog',
#   'geburt',
#   'hunterboots',
#   'homesweethome',
#   'stellakids',
#   'zitronensaft',
#   'vorfreude',
#   'love\\n.\\n.\\n.\\n.\\n#mamablog',
#   'palmenhauswien',
#   'feelings',
#   'mamastyle',
#   'mommyandhergirl',
#   "besteentscheidung',",
#   "instamom',",
#   'kindermode',
#   'wohnen',
#   'brotherandsister\\n.\\n.\\n.\\n.\\n#mamablog',
#   'armcandy\\n.\\n.\\n.\\n#mamablog',
#   'rooftopterrace',
#   'bademantel',
#   'vierjahrealt',
#   'hemademeamom',
#   'ootd',
#   'meinteam\\n.\\n.\\n.\\n.\\n#mamablog',
#   'englischergarten',
#   'frühlingimgarten',
#   'bipacard',
#   'unicornparty',
#   'summerishere',
#   'newshop',
#   'firstflowers',
#   'mallorca",',
#   'verkleiden',
#   'Samstag',
#   'mamablogger',
#   'rausfallschutz',
#   'ikeaküche',
#   'italy',
#   'shirababyclub',
#   'vsroom',
#   'feiertag',
#   'DirtisGood',
#   'thursdaymorning\\n.\\n.\\n.\\n.\\n#mamablog',
#   'regenbogentorte',
#   'beautybarvienna\\n.\\n.\\n.\\n#manikürewien',
#   'damussmandurch',
#   'gratefulforhavinggoodfriends',
#   'starman',
#   'regenbogendekoration',
#   'urlaubinkärnten',
#   'träumschön.',
#   'warsolustig,',
#   'manchesändertsichnie\\n.\\n.\\n.\\n.\\n#mamablogger',
#   'herbsferien',
#   'endofsummer',
#   'kidstent',
#   'leafblanket',
#   'batgirl',
#   'momstyle',
#   'sweetdreams',
#   'twinningiswinning',
#   'laleloo',
#   'urlaubaufmallorca',
#   'spielecke',
# ...
#   'gard?ropdetoksu',
#   'gard?ropdüzenleme',
#   'garden',
#   'gardirop',
#   'gardiropmagazin',
#   'getmymindright',
#   'getthelook',
#   'gianvitorossi',
#   'goldendays',
#   'gonna',
#   'goodmood',
#   'goodmorning',
#   "goodvibes',",
#   'gorgeous',
#   'gucci',
#   'guide',
#   'hadsomequalitytime',
#   'hair',
#   'haircolor',
#   'hairybelts',
#   'hakkinda',
#   "happenseveryday',",
#   'happiness',
#   "happyfriday',",
#   'harbiyeacikhava',
#   'hasbeenalongtime',
#   'haveacolorfulweek',
#   'haveaniceweek',
#   'haveastyle',
#   'helenmirren',
#   'hellosaturday',
#   'hellyes',
#   'highfashion',
#   "highfashion',",
#   'hm',
#   'hmevent',
#   'hmstudio',
#   'hope',
#   'houseofsunny',
#   'howtostyle',
#   'iaminlove',
#   "icon',",
#   'iconic',
#   'ideas',
#   'ifyouarecheapnothinghelps',
#   'ig_daily',
#   'igaddicts',
#   "igaddicts',",
#   'igers',
#   "igers',",
#   'igfashion',
#   'igs',
#   "igs',",
#   'impressed',
#   'ineedtochill',
#   'inlove',
#   'innovative',
#   'ins',
#   'inspace',
#   'inspiration',
#   'inspirational',
#   'inspire',
#   'inspired',
#   'inspires',
#   'inspiring',
#   'inspo',
#   'instaartist',
#   'instacool',
#   'instadaily',
#   "instadaily',",
#   'instafashion',
#   "instafashion',",
#   'instafollow',
#   'instafollow",',
#   "instafollow',",
#   'instagood',
#   'instagram',
#   'instagramer',
#   'instagramers',
#   "instagramers',",
#   'instagramhub',
#   'instagrammer',
#   'instalike',
#   "instalike',",
#   'instalikers',
#   'instalikes',
#   "instalikes',",
#   'instalove',
#   "instalove',",
#   'instame',
#   "instamoment',",
#   'instamood',
#   "instamovie',",
#   "instamusic',",
#   'instanature',
#   'instaphoto',
#   'instapic',
#   'instapic",',
#   "instapic',",
#   'instashop',
#   'instasize',
#   "instasize',",
#   'instastyle',
#   "instastyle',",
#   'ipeklikes',
#   'is',
#   'isontheway',
#   'istanbul',
#   'italia',
#   'italiansdoitbetter',
#   'itsprada',
#   'itspradababy',
#   'jacket',
#   'january',
#   'jasonwu',
#   'jeans',
#   'justsayin',
#   'kapakcekimi',
#   "karabatak',",
#   'karaköy',
#   'karllagerfeld',
#   'keepbelieving',
#   'keepbelievinginyourself',
#   'keepitcool',
#   'keepitsimple',
#   'keeploving',
#   'kids',
#   'kiniyoruz',
#   'lanvin',
#   'laperla',
#   'lastnight',
#   'latest',
#   'lazysunday',
#   'leatherjacket',
#   'lennykravitz',
#   'lennykravitzstyle',
#   'life',
#   'lifehappens',
#   'like',
#   'like4follow',
#   "like4follow',",
#   'like4klike',
#   'like4like',
#   "like4like',",
#   'like4likeback',
#   'like4likers',
#   "like4likers',",
#   'like4likes',
#   'likealways',
#   'likeback',
#   "likeback',",
#   'liked',
#   'likeforfollow',
#   'likeforfollow",',
#   "likeforfollow',",
#   'likeforlife',
#   'likeforlike',
#   "likeforlike',",
#   "likeforlikealways',",
#   'likeforlikes',
#   'likeforlikes",',
#   'likeforlive',
#   'likeforlivealways',
#   'likeforlove',
#   'likefortag',
#   'likeit',
#   "likeit',",
#   'likeme',
#   'likemyphoto',
#   'likemypic',
#   'likephoto",',
#   'liker4like',
#   'likers',
#   'likes',
#   "likes',",
#   'likes4like',
#   'likes4likes',
#   'likesforlikes',
#   'listenyoursoul',
#   'liveinthemoment',
#   "liveinthemoment',",
#   'londoner',
#   'look',
#   'lookbook',
#   "lookbook',",
#   'lookfashion',
#   'lookoftheday',
#   'louisvuitton',
#   'love',
#   'love",',
#   "love',",
#   'loveblack',
#   'loved',
#   'lovefashion',
#   'loveiseverywhere',
#   'loveisgonnasaveus',
#   'loveit',
#   'lovely',
#   'lovemagazine',
#   'lovemyjob',
#   'lovenature',
#   'loves',
#   'lovespring',
#   'lovestory',
#   'lovethecombo',
#   'lovethis',
#   'lovewhatyoudo',
#   'luxebelts',
#   'luxurypleasure',
#   'magazine',
#   "magazine',",
#   'magazineready',
#   'makeitcount',
#   'makeup',
#   'manolablahnik',
#   'march',
#   'march2017',
#   'marnikids',
#   'masculine',
#   'matchesfashion',
#   'matters',
#   'mavijeans',
#   'may',
#   'maybeitsjustme',
#   'me',
#   'memories',
#   'memyself',
#   'memyselfi',
#   'mens',
#   'mensclothing',
#   'mensdaily',
#   'mensfashion',
#   'mensfashionposts',
#   'menshealthmagazine',
#   'mensoutfit',
#   'mensstyle',
#   'mensstyleguide',
#   'menstyle',
#   'menswear',
#   'mensweardaily',
#   'menwear',
#   'message',
#   'micaarganaraz',
#   'minimal',
#   'minimalism',
#   'minimalist',
#   'minimalstyle',
#   'misssunnydays',
#   'miucciaprada',
#   'mixtures',
#   'moda',
#   'modaeditoru',
#   'model',
#   'models',
#   'momyandson',
#   'monday',
#   'monicabelluci',
#   'mood',
#   'moodyportrait',
#   'moresoul',
#   'morning',
#   'motivates",',
#   'motivation',
#   'motto',
#   'mottoforlife',
#   'movienight',
#   'moviequotes',
#   'movies',
#   'moviestar',
#   'music',
#   'musthave',
#   'mycapture',
#   'mycapture",',
#   'mycity',
#   'mylife',
#   'myseason',
#   'myview',
#   'nature',
#   'neverletmego',
#   'new',
#   'newcollection',
#   'newseason',
#   'night',
#   'nisantasi',
#   'nitenite',
#   'nlvogue',
#   'nomatterwhat',
#   'notsassy',
#   'notte',
#   'ny',
#   'of',
#   'ofme',
#   'oldschool',
#   'on',
#   'oneandonly',
#   'onewayticket',
#   'only',
#   'ootd',
#   'oversized',
#   'oversizedshirt',
#   'overthinking',
#   'ozlemsuer',
#   'pants',
#   'parents',
#   'parentsdergisi',
#   'paris',
#   'parçalar',
#   'patterns',
#   'paulsmith',
#   'peace',
#   'personalstyle',
#   'perspective',
#   'pfw',
#   'phoebephilo',
#   'photographer',
#   'photography',
#   'pics',
#   'picture',
#   'pictures',
#   'pinkisthenewblack',
#   'pinky',
#   'place',
#   'please',
#   'pointofview',
#   'portfolio',
#   'portrait',
#   'portraits',
#   'positivemindset',
#   'positivemovement',
#   'positivevibes',
#   'post',
#   'prada',
#   'pradabag',
#   'prayforistanbul',
#   'prayforpeace',
#   'prayfortheworld',
#   'press',
#   'pressday',
#   'pressevent',
#   'prettycool',
#   'prettylights',
#   'printonprint',
#   'production',
#   'qualitytime',
#   'quotes',
#   'ramsey',
#   'ready',
#   'readytowear',
#   'reallove',
#   'recent',
#   'rightdirection',
#   'rihanna',
#   'rip',
#   'ripamywinehouse',
#   'rockchic',
#   'runway',
#   'saintlaurent',
#   'saintlaurentparis',
#   'sandro',
#   'saturday',
#   'save',
#   'scotchandsoda',
#   'sculpted',
#   'sculptedwaves',
#   'season',
#   'secretgarden',
#   'self',
#   "self',",
#   'selfies',
#   'selfimprovement',
#   'selfportrait',
#   'sequins',
#   'sequinskirt',
#   'shinebabyshine',
#   'shinebrightlikeadiamond',
#   'shooting',
#   "shooting',",
#   'shortfilm',
#   'shotshotshot',
#   'show',
#   'shows',
#   'simplefashion',
#   'simplejoys',
#   'simplicityisbeauty",',
#   'skypics',
#   'sleeve',
#   'sohohouse#igers',
#   'sohohouseistanbul',
#   'sometimesyouhavetocreateyourownsunshine',
#   'sophialoren',
#   'sotrue',
#   'soul',
#   'soulmates',
#   'soulmatters',
#   'soulshine',
#   "sparklebaby',",
#   'spendsomequalitytime',
#   'spentsomequalitytime',
#   'spring',
#   'springday',
#   'springishere',
#   'springtime',
#   'staycool',
#   'stayfocused',
#   'staypositive',
#   'stellajean',
#   'stil',
#   'stildanismani',
#   'stiliniyarat',
#   'stilinolsun',
#   'stilllife',
#   'stillweekend',
#   'stilnedir',
#   'stiloneleri',
#   'stopterrorism',
#   'stories',
#   'story',
#   "story',",
#   'streetfashion',
#   'streetstyle',
#   'structure',
#   'studio',
#   'style',
#   'style",',
#   "style',",
#   'styleaddict',
#   'styleblogger',
#   "styleblogger',",
#   'styledbyme',
#   'stylediaries',
#   "stylediaries',",
#   'stylediary',
#   'stylefashion',
#   'styleguide',
#   'styleicon',
#   "styleideas',",
#   'styleinspo',
#   "styleinspo',",
#   'styles',
#   'styling',
#   "styling',",
#   'stylingbyme',
#   'stylingteam',
#   'stylist',
#   "stylist',",
#   'stylistchoice',
#   "stylistchoice',",
#   'stylistlife',
#   'stylistpicks',
#   'stylists',
#   'summer',
#   'summerlove',
#   'summerlovin',
#   'summertime',
#   'summertimesadness',
#   'summertimeshine',
#   'summervibes',
#   'sunday',
#   'sundaymood',
#   'sundays',
#   'sundayvibes',
#   'sunlight',
#   'sunshine',
#   'tagsforlikes',
#   "tagsforlikes',",
#   'tagstagram',
#   'takeadeepbreath',
#   'takemethere',
#   'tav?r',
#   'tavsiyeediyorum',
#   'tb',
#   'tbt',
#   'teamjob',
#   'textile',
#   'tgif',
#   'thankful',
#   'thatswhatiwant',
#   'the',
#   'thecoolest',
#   'theory',
#   'therightdirection',
#   'therow',
#   'thewayofthinking',
#   'thinking',
#   'thinkingoutloud',
#   "thinkup',",
#   'thisishowwedoit',
#   'thisisonmymind',
#   'thoughts',
#   'thursday',
#   'tibiresort17',
#   'time',
#   'timeflies',
#   'timeflieswhenyourehavingfun',
#   'timeless',
#   "timeless',",
#   'timeout',
#   'tired',
#   'today',
#   "today',",
#   'tomford',
#   'tomtom',
#   'tonight',
#   'trenchcoat',
#   'trendsettermagazine',
#   'truestory',
#   'truth',
#   'trymore',
#   'turkey',
#   'turkishdesigner',
#   'unbelivable',
#   'vakko',
#   'vb',
#   'vibes',
#   'victoriabeckham',
#   'video',
#   'view',
#   'vision',
#   'visualartist',
#   'vogue',
#   'vogueitalia',
#   'walterchin',
#   'wave',
#   'wearlikeucare',
#   'wednesday',
#   'week',
#   'weekend',
#   'wellsaid',
#   'whatacatch',
#   'whataninspriationalshot',
#   'whataword',
#   'whatisyourcolor',
#   'white',
#   'whiteisthenewblack',
#   'wishiwasthere',
#   'woman',
#   'womenfashion',
#   'womensfashion',
#   'womenshealth',
#   'words',
#   'works',
#   "works',",
#   'world',
#   'worldpeace',
#   'wow',
#   'ya?s?zkad?nlar',
#   'yesicandoit',
#   'yesplease',
#   'yeter',
#   'ysl',
#   'zamans?z',
#   'özlemsüer'},
#  {'1',
#   '3d',
#   '70sfashion',
#   '?",',
#   "?',",
#   '??',
#   'AMERICAHATESUS',
#   'AdoptDontAhop',
#   'Apple',
#   'BeautifulTO',
#   "BlackberryMotion',",
#   "BoughtItForTheGram',",
#   'CNE2017',
#   'Canada150\\xa0',
#   "CanadaDay',",
#   'ClimateChange',
#   'CoolCans',
#   'CraftBeer',
#   'DanceCentral',
#   "DopeTech',",
#   'DuoLingo',
#   'FrontRow',
#   'GOVBALLNYC',
#   "GOVBALLNYC',",
#   'GovBall',
#   'GovernorsBall',
#   'Haliburton',
#   'HockeyWives',
#   'IBoughtThis',
#   'IvyPark",',
#   "JamesComey',",
#   'LVAHHowl",',
#   'LeJardin',
#   "LookCarefully',",
#   'May24',
#   'MicrosoftSurface',
#   'Murrica',
#   "NaeNae',",
#   'Nature',
#   'NotAnAd',
#   'OldMill',
#   "OntarioPlace',",
#   'PSY',
#   'ParisAgreement',
#   'RTZ',
#   'Ripleys',
#   'SalmonMigration',
#   'StandForCanada',
#   'SurfaceStyle',
#   'TOMBOBNYC',
#   "ThanksDonald',",
#   "Toronto',",
#   'TorontoNature',
#   'TorontoSalmon',
#   'Touchbar',
#   'Tweed',
#   "TwitterDotCom',",
#   'VIP',
#   'WeTheNorth',
#   'Xbox',
#   'acrobatics',
#   "ad',",
#   "adolescentclothing',",
#   'aerialyoga',
#   'airdry',
#   'airdrying',
#   'airshow',
#   'airshow2017",',
#   'art',
#   "avocadotoast',",
#   'babiesofinstagram',
#   'babybird',
#   'backtattoo',
#   "ballz',",
#   'bananas',
#   'baobaoisseymiyake',
#   'baobaoisseymiyake",',
#   'batmantattoo',
#   'bday',
#   'beautyandthebeast',
#   'beautycat',
#   'bellwoods',
#   "bellwoods',",
#   'beourguest',
#   'best',
#   "best',",
#   'besties',
#   'beyonce',
#   'beyoncebabies",',
#   'bgood',
#   'bigrubberduck',
#   'birdfeeder',
#   'birds',
#   'birdsofinstagram',
#   'blackicecream',
#   'blessed',
#   "blessedartthouamongstgangsters',",
#   'blonde',
#   'bluejays',
#   'bmofield',
#   'boxerbraids',
#   'boyswithmakeup',
#   'braids',
#   'camptimberlane',
#   'camptimberlane",',
#   "camptimberlane',",
#   'canada',
#   'canada150',
#   'canadaduck',
#   "catbreakfast',",
#   'catcafe',
#   'catfistbump',
#   'cathalloweencostume',
#   'cathidingskills',
#   'cathighfive',
#   'cats',
#   'catsandgrapes',
#   'catsdofacetime',
#   'catsofinstagram',
#   'chancetherapper',
#   'charliehunnam',
#   'cherryblossom',
#   'cherryblossoms',
#   'cherryblossomtree',
#   'circus',
#   'cne2017',
#   'collection",',
#   'cooldotcombro",',
#   "cornporn',",
#   'cottoncandyhair',
#   "couch',",
#   "couplesofinstagram',",
#   'crestedgecko',
#   'cresties',
#   'crestiesofinstagram',
#   "crestiesofinstagram',",
#   'crunchclean',
#   'cute',
#   "cuteblondesdotcom',",
#   'cutehairstyles',
#   'cuteness',
#   'cutesweaterthough',
#   'cutiebaby',
#   'dance',
#   'daschund',
#   'daschundpuppy',
#   'daschundsofinstagram',
#   "deadbabyjokes',",
#   'dogsofinstagram',
#   'dogsofliberty',
#   'dragonkitty',
#   'drizzy",',
#   "drizzy',",
#   "drstevebrule',",
#   'dudebox',
#   "eclipseto',",
#   'emptytrain',
#   'faketatoo',
#   'fashionbaby',
#   'fencehopping',
#   'festivalfashion',
#   'festivalhair',
#   'festivalhairstyles',
#   'festivalseason',
#   'finches',
#   "finches',",
#   'finchesofinstagram",',
#   'fitfam5000",',
#   'fitness',
#   'flatlay',
#   'floodylikewoah",',
#   'foodporn',
#   'freshii',
#   'friggincats',
#   'fun',
#   'funko',
#   'funkopop',
#   'futurpreneur',
#   'gecko',
#   'geckosofinstagram',
#   "girlsoftoronto',",
#   'gogopowerrangers',
#   'gojaysgo',
#   'goleafsgo',
#   'goleavesgo',
#   'goraptors',
#   'got2standout',
#   "got2standout',",
#   'gothicecream',
#   'govballnyc',
#   "govballnyc',",
#   "grammarpolice',",
#   'grapes',
#   "guala',",
#   "guyritchie',",
#   'haircolor',
#   'hairspo',
#   'hairspo",',
#   'hairstyles',
#   'hairtalk',
#   'halloweencat',
#   "happycrunching',",
#   'happystpatricksday',
#   'harambediedforoursins',
#   "hashtag',",
#   'healthyfood',
#   'hockeyisboring',
#   'homies4lyfe',
#   'inauguration',
#   'inauguration2017',
#   "indianfood',",
#   "inked',",
#   'inkedgirls',
#   'instamodel',
#   "irishbetch',",
#   'janandwayneskylar',
#   'janethevirgin',
#   'janskylar',
#   'jkcatsdontdofacetime",',
#   'johnmayer',
#   'jokethreads',
#   'kale',
#   'kalechips',
#   'kardashianfamily',
#   'kingarthur',
#   'kingarthurlegendofthesword',
#   'kittyfistbump',
#   'korea',
#   "kuwtk',",
#   'labourdaylongweekend',
#   "ladieswholunch',",
#   'lakeontario',
#   'letsgototheex',
#   'libertyvillage',
#   "libertyvillage',",
#   "macbookpro',",
#   'mapleleafs',
#   "may24',",
#   'mediamatters',
#   'millennialsamirite',
#   'mohawk',
#   'mohawkdog',
#   'mood',
#   "mood.',",
#   "morningpics',",
#   'obama4life",',
#   "ok',",
#   'ootd',
#   "ootd',",
#   'orangekitty",',
#   'peanutbutter',
#   'peibrewingcompany',
#   'periscope',
#   'piercedbraids',
#   'pinkleatherjacket',
#   'pizzaparty',
#   'pokemongo',
#   'pokemongo",',
#   "pokemongo',",
#   'poopcafe',
#   'poopcafetoronto',
#   'poptoys',
#   'pornporn',
#   'powerrangers',
#   "pretty',",
#   'privatejet',
#   'privatetrain',
#   'proteinchips',
#   'raptors',
#   'reptilesofinstagram',
#   "revivme',",
#   "ripwmcfw',",
#   'risk',
#   'rogeliodelavega',
#   "royalagriculturalwinterfair',",
#   "rubberducky',",
#   "ryvita',",
#   'sailormoon',
#   'salmon',
#   'shareachair',
#   "siamese',",
#   'silks',
#   "sleepingkitty',",
#   'sleepycat",',
#   'slowmotion',
#   'snarkyaf',
#   'snl',
#   'snow',
#   'snowmotion',
#   'snowto',
#   'solareclipse',
#   'solareclipse2017',
#   "somethingaboutyouandyouneedtoknow',",
#   'spidermanhomecoming',
#   'spoooorts',
#   'sportssportssports',
#   "stayweird',",
#   'steamedgreens",',
#   'still',
#   'summer',
#   "sunbathing',",
#   "sundayfunday',",
#   'sunsetsoiree',
#   'surfacelaptop',
#   "surfacelaptop',",
#   'surfacestyle",',
#   'sushiburrito',
#   'tattoo',
#   'teddyursa",',
#   'the6ix',
#   "therecroomtoronto',",
#   'thirtyflirtyandthriving",',
#   'tickory',
#   'timanderic',
#   'timandericawesomeshowgreatjob',
#   'tiw2017',
#   "tiw2017',",
#   'tonkinese',
#   'tonkinesecats',
#   'tonks',
#   'tonksofinstagram',
#   'toronto',
#   "toronto',",
#   'torontobirds',
#   'torontocats',
#   'torontoduck',
#   "torontoeats',",
#   'torontogallery",',
#   'torontoislands',
#   "torontoweather',",
#   'totcafe',
#   'tresspassing',
#   'trinitybellwoods',
#   'twoislands',
#   'twoislandsweekend',
#   'unicornhair',
#   'veganfood',
#   'vegetables',
#   'waterlevels',
#   'weird',
#   'why',
#   'widelegjeans',
#   'wildlife',
#   'winter',
#   'wizkatlifa',
#   "wokethreads',",
#   'wut',
#   "wut',",
#   'xperiaclimb',
#   "yup',"},
#  {'2017calendar",',
#   '?',
#   "?',",
#   'Iceland',
#   'airbnb",',
#   'allarewelcome',
#   'branding',
#   'bridgehampton',
#   'brooklyn',
#   "brooklyn',",
#   'california',
#   'centralcoast',
#   'chinatown',
#   'crosscountryroadtrip',
#   'danflavin',
#   'danflavinartinstitute',
#   'design',
#   'designinspiration',
#   'designinspo",',
#   "dextergramd',",
#   "diaartfoundation',",
#   'dimsum',
#   'dougaitken',
#   'doñaelba',
#   'earthday',
#   'easternpkwybk',
#   'elcaminotravel',
#   "elcaminotravel',",
#   "everyday',",
#   "exploreresponsibly',",
#   'granada',
#   'graphicdesign',
#   "homeawayfromhome',",
#   'hulakaihotel',
#   'humantogether',
#   "isletaelespino',",
#   "iwasrunningdownlikecrazy',",
#   "jungalowstyle',",
#   'jysinsingapore',
#   'jysxgopcollab',
#   'katiforner',
#   'losangeles",',
#   'mirage',
#   'myparachutehome',
#   'myparachutehome",',
#   'mystichotsprings',
#   'nationalsiblingday',
#   'newmexico',
#   'newyork',
#   "newyork',",
#   'newyorkcity',
#   'nicaragua',
#   "nicaragua',",
#   'nomwahteaparlor',
#   'nyc',
#   'nyc",',
#   "nyc',",
#   'nycspring',
#   'oneyearago',
#   'parkslope',
#   'poketoworkshop",',
#   'poketoworkshops',
#   'poketoworkshops",',
#   'selftimer',
#   "solareclipse',",
#   'springinnyc',
#   "springinnyc',",
#   'superbloom',
#   'taos',
#   "thecrossroadsofshouldandmust',",
#   "thegoodsort',",
#   'tygershark',
#   'utah",',
#   'whitesandsnationalmonument',
#   'womensmarch',
#   "womensmarchonwashington',",
#   'yeswedid',
#   "zenhaven',"}]

# %%
for i,v in enumerate(data.caption):
    print(v)
# Out:
# ['Happy Halloween from Han Solo and Princess Leia! May the Force Be With You! @rickz903 Thanks for the photoshop skills @ratscape #buns #hansolo #princessleia #couplescostume #fun #marriedlife #halloween #starwars', 'A little #tbt to last years Cruella de Ville costume! Halloween is my FAVE holiday and I cant wait to show you guys what the hubs and I put together for tomorrow! Its out of this world! ? What are you dressing up as?  #Halloween #costumes #fun #Cruella #disneyvillain #halloweenmakeup', 'Cant wait for tomorrow!!!! I hope to see all you babes from 1-4 pm while I host the 1 year anniversary party for @kendrascott @fashionvalleyca \nJewelry, Cocktails, Dessert and Custom Calligraphy!! ?\n?20% of all proceeds will be donated to @breastcancerangels to help support breast cancer awareness month. ?Also, if your birthday is in the month of October youll receive 50% of any one item in the store! ?Signature Kendra Rose pink drink by @youandyourssd. Its Saturday lets party!??\n? @lindsmariephoto', 'What dreams are made of!?? Met @rickz903 for lunch and a sneak peek/treat at the new @shakesh
# ['expose yourself to your deepest fear; after that, fear has no power, and the fear of freedom shrinks and vanishes. you are free. -jim morrison #aiweiwei #goodfencesmakegoodneighbors', 'they who would travel happily must travel light. -antoine de saint-exupéry #imissparis', 'find joy in the sky, in the trees, in the flowers. there are flowers everywhere for those who want to see them. -henri matisse', "it's not where you are but where you feel you should be. it's where your heart is. -the cleaners from venus", 'you do not do evil to those who do evil to you, but you deal with them with forgiveness and kindness. (on the wall at a coffee shop this morning)', 'risk more than others think is safe. care more than others think is wise. dream more than others think is practical. expect more than others think is possible.\r\n-claude bissell', 'stay close to people who feel like sunlight.', "it's not where you take things from - it's where you take them to.\r\n-jean-luc godard\r\n\r\n#dappled #cinematic #dreams", "taken at a favorite music venue that's been in the line of fire. heartbroken over the devastation in northern california, which will always be a home away from home.", 'my heart goes out to one of my favorite places. i hope that all affected, and your families and friends are safe.', 'there is nothing like a dream to create the future. -victor hugo', "no artwork can be understood. it can be only perceived. we're listening to what we have inside ourselves... we hear or see in an artwork what we have experienced and what we want to experience... there is no such thing as a qualified listener. we're all equally qualified. the people with a lot of experience and the people with zero experience. we all hear something about ourselves and this is Rèpons. -matthias pintscher #paarepons", 'what plagues and pursues us on an inner level has a way of manifesting itself in our environment in the form of people, events, and issues that appear to be beyond our control. but all these external expressions are reflections of our insides, and it is inside ourselves that we can safely experiment with surrendering to what we fear and dislike. it may feel scary, and we may find ourselves in the company of a lot of resistance as we begin the process of opening to what we fear. but the more we learn to surrender, and the more the demons that plague us disappear in the process, the more courageous we will become. -magical words of wisdom today by @dailyom', 'two uses we can put our imaginations to - anxiety and creativity.\r\n-deepak chopra', 'to put everything in balance is good, to put everything in harmony is better. -victor hugo', 'find joy in the sky, in the trees, in the flowers. there are flowers everywhere for those who want to see them. -henri matisse', 'even the darkest night will end and the sun will rise. -victor hugo', 'my destination is no longer a place, rather a new way of seeing. -marcel proust', 'if you are lucky enough to have lived in paris, then wherever you go for the rest of your life, it stays with you, for paris is a moveable feast. -hemingway', 'ready to move in.', 'architecture is inhabited sculpture. -constantin brâncu?i #brancusi', 'language will never quite connect you to the world.', 'walk the walk, talk the talk and laugh and love in between. ? @cynisaunicorn #lestyleàlafrançaise', 'between the lines.', 'this is love: to fly toward a secret sky, to cause a hundred veils to fall each moment. first to let go of life. finally, to take a step without feet. -rumi', "as water reflects the face, so one's life reflects the heart. -proverb", 'dream digs.', 'tangerine dream. #goodnightsweetheart #ilovenewyork', 'let yourself be silently drawn by the stronger pull of what you really love. -rumi', 'a new moon teaches gradualness and deliberation and how one gives birth to oneself slowly. patience with small details makes perfect a large work, like the universe.\r\n-rumi', 'and about emotions: all emotions are pure which gather an ...
esterday... an ode to the the beloved Aussie institution that is the milk bar. Check it: fooderati.com.au/media ?: @daisysmilkbar ? Thanks to @janelawsonfood for your help x #bringbacktheclassics #sbsfood', 'A very stylish afternoon at Dior with a very stylish woman @little_girl_arise ??', 'If in doubt, punch it out. ?', 'Chinese chicken, tofu and mushroom stew makes a solid deadline dinner.', 'Getting twiggy with it. ?', 'One of my most favourite parts of the week, picking out @themayfairrestaurant blooms with Nadine from @azalea_florist. ??', 'Never jump(suit) to conclusions. #rollas', 'When your mate shoots with your husband and it ends up in motor boating cocktails. @kristofferpaulsen @joeyromeolane you guys are one out of the box.', 'Margherita Saturdays with legends.', 'If anyone needs me, Ill be at the bar. #platdujour', 'Beyond the golden hour', 'Super psyched to announce that Im headed to @gourmetescape this Nov 16-19 to MC a bunch of brilliant events including total food heroes @rick_stein @alexatala and absolute legends Paul Carmichael from @momofukuseiobo as well as the @portenosydney crew. I promise not to wear vegetables as clothing. .\n.\nP.s And if you have any burning questions for any of these culinary greats, let me know and Ill ask!', 'Dessert for dinner. All in the name of research again, of course.??', 'Reckon I have the edge over picking up the bartender here, seeing as were already married ???', 'I love that I get to call eating ...
# ['The Start of Summer ? Testing our the new #GooglePixel2 - which, for an Apple fan, Im obsessed with it. ? #giftsfromgoogle #teampixel', 'Get lost in adventures, and find yourself ? @ausoutbacknt', 'Home is not where you are from, it is where you belong. Some of travel the whole world to find it. Others, find it in a person @beautaplin ?', 'Make each day count. Spend your time with people, who actually want to be in your life ?', '\'None of us are getting out of here alive, so please stop treating yourself like an after thought. Eat the delicious food. Walk in the sunshine. Jump in the ocean. Say the truth that youre carrying in your heart like a hidden treasure. Be silly. Be kind. Be weird. Theres no time for anything else." - Christopher Walkin', 'Reminiscing over one of the most beautiful sunrises to date. ? @australia', 'Wandering through the wildflowers ?', 'Take me back ?? @ausoutbacknt #animatededitseries', 'Same time, every year. Always back here searching for Cherry Blossoms ??', 'You, me and the sea ? #animatededitseries', 'Jobs fill your pockets. Adventures fill your soul', "Home, away from home ??? Can't wait to be back next week @visitnsw @bluemountainsaustralia", 'Head in the clouds... ???', 'Follow the path, less travelled', 'Let your dreams set sail #animatededitseries', 'Fill your life with adventures, not things. Have stories to tell, not things to show. ??', "'Love her, but leave her wild' ?? @atticuspoetry", 'Life begins when you step out of your comfort zone, and start challenging yourself. ?', 'Adventure often ?', "It's about the journey, not the destination.", 'Life is an adventure- or nothing. ??', 'What is life, but one grand adventure. ?', 'Dreaming of my favourite city ??', 'Every morning you have two choices: continue to sleep with your dreams, or wake up and chase them.', 'One of the most incredible places I have ever visited ? @visitjapanau', 'Sailing on the top of Australia ?', "It's interesting how we always want to travel the world to see it all, but a lot of us have hardly seen our own backyard in our own countries. @ausoutbacknt you were something else ?", "'Photographs are a way of time travel.'", 'Cheeky little thing. Just look at that face ?? @visitjapanau', 'Sometimes the adventures that you never quite expect, are only just around the corner ???', 'Sometimes we need reminding of how small we are, in such a big world, yet still realise how much we can achieve. ??', 'Caught snapping the golden sunrise in @queensland last year ?
table, and even simple acts like grocery shopping or FaceTiming with our friends on the other side of the world. I read recently that the quickest way to change yourself is to hang out with people who are already the way you want to be. That, I can say is 100% true. Thank you Ellen, for being you.", 'Clarity, in Premià de Mar.', 'It was a beautiful day in the neighborhood.', 'I dreamt of being at the Colosseum with my nephew a few months ago and my dream came true this week. ??I love you, Milo bear.', 'It was grand!', 'Always on the hunt for green ?...', 'On the go for a month and this is my only consistency from day to day. Setting daily intentions and affirmations for a new season around the corner. Morning and evening gratitude scribbles filling the pages.  Italy currently, Spain soon...', 'QT with this QT', 'yesterday, in all her glory.', 'Deep Breathing', "Tomorrow! Will I see you at @thelinehotel hotel? I'm teaching a workshop on how to use your DSLR to its fullest potential to have more creative freedom and communicate your vision through your photography. Last minute signups are welcome! The link to join is in my Stories. See you there! @poketo #poketoworkshop", '"My purpose in acquiring the property was simply and wholly that I might build a trail to the summit ." Henry Biddle purchased this rock in 1915 for $1 and created a three-quarter mile trail to the top by 1918. It became a state park in 1935. Thank you, Henry Biddle!! ??', '? sounds of totality ? #solareclipse', 'safety first', "There are a still a few spots left in the workshop I'm teaching at @thelinehotel next weekend. Come learn how to use your DSLR camera to its fullest potential to communicate your vision through your photography. The link is in my profile to join (or check my stories). Thanks to those that have signed up already--looking forward to meeting you! @poketo #poketoworkshops #losangeles", "Just enjoying my aunt's flowers and the pink Members Only jacket I found in her closet.", 'Charmed in the PNW. ?', "Goodbye, my beautiful city. See you in the fall (miss you already ?). ??\r\n\r\nHeaded to the West Coast for some work/some play (anyone going to be in PDX for the eclipse?). On a semi-related (work) note, I've been getting a few questions about the upcoming workshop I'm teaching in LA at @thelinehotel on the 26th. Some of you have asked if you can come if you don't have a DSLR, and the answer is YES, you can still join, and yes, you will still learn ways to improve your photos through shooting and editing. Bring what you have. At the heart of it, the workshop will be about how best to communicate your vision through your photography by using the equipment that you do have to its fullest potential. If you're on the fence about joining/have any questions, feel free to DM me or see the link in my profile for more info. Come one, come all! #allarewelcome @poketo #poketoworkshops", 'coney-island-self-portrait // 080417', "FREE yoga at Fort Greene Park every Saturday at 11AM until Oct. 14 ...

# %%
# Milano

userlist=[]
emojis = []
usernameforeachpost  = []
f2hashtag = []
f3post = []

captionsfromsample = dftest
#captionsfromsample.drop(['level_0', 'index', 'Unnamed: 0'], axis =1, inplace = True)

listof = []
for num, singlepost in enumerate(captionsfromsample.caption): 
    ## f1 separates by user. This is each user's total supply of posts
    f1 = singlepost.split("\', \'")

    # take only the first quarter of their text
    total= (len(f1)/4)
    f1 = f1[0:int(total)]

    f3 = []

    #for i in (range(len(f1))):
    #    userlist.append(dftest.username)"""
    
    for j,k in enumerate(f1):

        userlist.append(dftest.username[num])
        
        f2 = (f1[j].replace("\n", " ")).replace("\\", "")
        
        #get emojis
        emoji = re.findall(r'[^\w\s,]', f2)
        emojis.append(emoji)
        
        f2post.append(f2)
        f3post.append(f3)
        f3.append(f2)
        #usernameforeachpost.append(dftest.username[num])

        
print(len(f2), len(f2hashtag), len(f3post), len(emojis), len(userlist))
