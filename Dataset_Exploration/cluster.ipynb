# %%
http://web.cs.ucdavis.edu/~filkov/classes/234-S08/secure/clustering.pdf
# Out:
#   File "<ipython-input-56-f1fa54cd0501>", line 1
#     http://web.cs.ucdavis.edu/~filkov/classes/234-S08/secure/clustering.pdf
#           ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np
import datetime as DT
import matplotlib.pyplot as plt
from statsmodels.tools import add_constant
from statsmodels.regression.linear_model import RegressionResults
import seaborn as sns
import sklearn as sk
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.preprocessing import PolynomialFeatures
from sklearn.neighbors import KNeighborsRegressor
from sklearn.decomposition import PCA
from sklearn import tree
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn import ensemble
#import pydotplus
#import io
import collections
from sklearn.tree import export_graphviz
from IPython.display import Image
from IPython.display import display
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cmx
import matplotlib.colors as colors
import matplotlib.patches as patches

# %% [markdown]
# to do:
# - Merge

# %%
data = pd.read_csv('emporiosirenuse_community_stat.csv',sep=",")

# %%
data.head()
# Out:
#              brandname  followers  processedUsers  privateUsers  nopostsUsers  \
# 0       muzungusisters      66938           22637         34576          3958
# 1  miguelinagambaccini      83848            5634         32186         12930
# 2           zeusndione      27624           11384         13540          1694
# 3            dodobaror      89500           31772         40838          6527
# 4   lisamariefernandez      83411           26993         38743          5193
#
#    missingUsers  %communityCovered  #communityPosts
# 0          8016              88.03          2910277
# 1         43561              47.11           670195
# 2          1899              93.14          1170628
# 3         13613              84.80          2974526
# 4         15327              81.63          3230855

# %%
data2 = pd.read_csv('emporiosirenuse_domain_stat.csv',sep=",")
data2.head()
# Out:
#              brandname  #posts  %geolocated  #uniquelocations   #like  #tag  \
# 0  miguelinagambaccini     274        60.58                99  139228  1116
# 1       muzungusisters     262        35.50                48  194003   194
# 2           zeusndione     206        20.87                31  131323  1257
# 3            dodobaror      83        27.71                20   98276    25
# 4   lisamariefernandez     335        75.52                96  213419   700
#
#    #comments  #mentions  #picturetag  #followers
# 0        921        448          460       82358
# 1       2588        497           79       66950
# 2        883        283          162       27673
# 3       1563        556          355       89562
# 4       3096        728          553       83421

# %%
frames = [data, data2]

result = pd.merge(data, data2, on='brandname', how='outer')

# %%
data2
# Out:
#                 brandname  #posts  %geolocated  #uniquelocations   #like  \
# 0     miguelinagambaccini     274        60.58                99  139228
# 1          muzungusisters     262        35.50                48  194003
# 2              zeusndione     206        20.87                31  131323
# 3               dodobaror      83        27.71                20   98276
# 4      lisamariefernandez     335        75.52                96  213419
# 5         athenaprocopiou     153        66.01                48   96811
# 6         emporiosirenuse     129        82.17                14   20208
# 7          heidikleinswim     322        51.86                59   62026
# 8            loupcharmant     280        20.00                32   55663
# 9  daftcollectionofficial      89         8.99                 7   12868
#
#    #tag  #comments  #mentions  #picturetag  #followers
# 0  1116        921        448          460       82358
# ...

# %%
for i in range(10):
    print(df.brandname[i], y_kmeans[i])
# Out:
# muzungusisters 2
# miguelinagambaccini 3
# zeusndione 1
# dodobaror 2
# lisamariefernandez 0
# athenaprocopiou 1
# emporiosirenuse 1
# heidikleinswim 1
# loupcharmant 1
# daftcollectionofficial 1

# %%
result
# Out:
#                 brandname  followers  processedUsers  privateUsers  \
# 0          muzungusisters      66938           22637         34576
# 1     miguelinagambaccini      83848            5634         32186
# 2              zeusndione      27624           11384         13540
# 3               dodobaror      89500           31772         40838
# 4      lisamariefernandez      83411           26993         38743
# 5         athenaprocopiou      26591           10215         12229
# 6         emporiosirenuse       3113            1552          1374
# 7          heidikleinswim      27426            8695         15330
# 8            loupcharmant      20446           12172          4933
# 9  daftcollectionofficial       3782            2619           595
#
#    nopostsUsers  missingUsers  %communityCovered  #communityPosts  #posts  \
# 0          3958          8016              88.03          2910277     262
# 1         12930         43561              47.11           670195     274
# ...

# %%
# normalize so Euclidean isnt affected
# split data into X and y
y = result['brandname']
X = result[result.columns[result.columns != 'brandname']]

# Normalize X's
X = (X - X.mean()) / (X.std())

# rebuild full data set with normalized values
df = pd.DataFrame(y).join(X)

# %%
df
# Out:
#                 brandname  followers  processedUsers  privateUsers  \
# 0          muzungusisters   0.695575        0.896424      0.964586
# 1     miguelinagambaccini   1.192495       -0.747847      0.812333
# 2              zeusndione  -0.459715       -0.191795     -0.375499
# 3               dodobaror   1.358586        1.779822      1.363503
# 4      lisamariefernandez   1.179654        1.317670      1.230042
# 5         athenaprocopiou  -0.490071       -0.304842     -0.459015
# 6         emporiosirenuse  -1.180000       -1.142596     -1.150526
# 7          heidikleinswim  -0.465533       -0.451834     -0.261468
# 8            loupcharmant  -0.670649       -0.115591     -0.923802
# 9  daftcollectionofficial  -1.160341       -1.039412     -1.200152
#
#    nopostsUsers  missingUsers  %communityCovered  #communityPosts    #posts  \
# 0      0.172278     -0.097313           0.347457         1.209832  0.515396
# ...

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=4)
kmeans.fit(X)
y_kmeans = kmeans.predict(X)

# %%
for i in range(10):
    print(df.brandname[i], y_kmeans[i])
# Out:
# muzungusisters 2
# miguelinagambaccini 3
# zeusndione 1
# dodobaror 2
# lisamariefernandez 0
# athenaprocopiou 1
# emporiosirenuse 1
# heidikleinswim 1
# loupcharmant 1
# daftcollectionofficial 1

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3)
kmeans.fit(X)
y_kmeans = kmeans.predict(X)

for i in range(10):
    print(df.brandname[i], y_kmeans[i])
# Out:
# muzungusisters 1
# miguelinagambaccini 2
# zeusndione 0
# dodobaror 1
# lisamariefernandez 1
# athenaprocopiou 0
# emporiosirenuse 0
# heidikleinswim 0
# loupcharmant 0
# daftcollectionofficial 0

# %% [markdown]
# Things to ask WP Monday @ 10AM:
#
# about the cluster:
# - We don't have data on the actual followers (i.e. ndeosrnenney. All we see if that he/she follows one of the brands...not how many followers, posts, etc).
# Instead- I clustered the diff companies on multi-D planes, and limited k means to 3 and 4:
# - how to tell what its picking up on?
# - I could do PCA then cluster- but it seems MORE diff to interpret
