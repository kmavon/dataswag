# %%
import pandas as pd
import numpy as np
import datetime as DT
import matplotlib.pyplot as plt
from statsmodels.tools import add_constant
from statsmodels.regression.linear_model import RegressionResults
import seaborn as sns
import sklearn as sk
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.preprocessing import PolynomialFeatures
from sklearn.neighbors import KNeighborsRegressor
from sklearn.decomposition import PCA
from sklearn import tree
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn import ensemble

import collections
from collections import Counter

#import pydotplus
#import io
import collections
from sklearn.tree import export_graphviz
from IPython.display import Image
from IPython.display import display
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cmx
import matplotlib.colors as colors
import matplotlib.patches as patches



data = pd.read_csv('sales_2016-01-01_2017-12-21.csv',sep=",")

# %%
df2 = data.apply(lambda x: x.astype(str).str.lower())

a = df2.groupby('product_type').count()['gross_sales']
adf = a.sort_values().reset_index()[-10:]
adf = adf.sort_values(by = ['gross_sales'], ascending=False)
top10produce= adf
top10produce


ind = np.arange(10)
#plt.bar(intop10['Billing city'], top10['gross_sales'], color="b")
top10produce = pd.DataFrame(top10produce)

top10produce['product_type'].unique()



ind = np.arange(10)
#plt.bar(intop10['Billing city'], top10['gross_sales'], color="b")
plt.bar(ind,top10produce['gross_sales'], color="purple")
plt.xticks(rotation=90)
plt.xticks(ind, ['caftan', 'dress', 'top', 'glass cup', 'swimming trunks',
       'cushion case', 'shirt', 'pants', 't-shirt',
       'bathing suit/one piece'])
plt.xlabel("Products")
plt.ylabel("Number of Products Sold")
plt.title('Top 10 products sold')
plt.savefig("KKKKKKKKKKKKKKKKtop10products.svg")
plt.figure(figsize=(12,12))

plt.show()

top10produce['product_type'].unique()

## need to be cleaned!!
# Out:
# array(['caftan', 'dress', 'top', 'glass cup', 'swimming trunks',
#        'cushion case', 'shirt', 'pants', 't-shirt',
#        'bathing suit/one piece'], dtype=object)

# %% [markdown]
# a = data.groupby('product_type').count()['gross_sales']
# adf = a.sort_values().reset_index()[-10:]
# adf = adf.sort_values(by = ['gross_sales'], ascending=False)
# top10country= adf
#
# ind = np.arange(10)
# #plt.bar(intop10['Billing city'], top10['gross_sales'], color="b")
# top10country = pd.DataFrame(top10country)
#
# #print(top10country['Billing country'].unique())
#
# ind = np.arange(10)
# #plt.bar(intop10['Billing city'], top10['gross_sales'], color="b")
# plt.bar(ind,top10country['gross_sales'], color="b")
# plt.xticks(rotation=90)
# plt.xticks(ind, ['United States', 'United Kingdom' ,'Italy' ,'Bahrain', 'Australia', 'France'
#  ,'Germany', 'Switzerland', 'Netherlands', 'Greece'])
# plt.xlabel("Gross Sales")
# plt.ylabel("Top 10 Countries")
# plt.title('Top 10 countries contributing to gross sales')
# plt.figure(figsize=(12,12))
# plt.savefig("top10countries.svg")
# plt.show()

# %% [markdown]
# delay = data
# labels2, values2 = zip(*Counter(delay['product_type']).items())
# indexes2 = np.arange(len(labels2))
# width = 1
# plt.bar(indexes2, values2, width, color="r")
# plt.xticks(indexes2 + width * 0.5, labels2)
# plt.xlabel("Product Type")
# plt.ylabel("Number of Sales")
# plt.xticks(rotation=90)
# plt.title('Number of Sales by Product')
# plt.figure(figsize=(12,12))
# plt.savefig("Number_sales_by_product.svg")
# plt.show()

# %%
a = data.groupby('Billing country').count()['gross_sales']
adf = a.sort_values().reset_index()[-10:]
adf = adf.sort_values(by = ['gross_sales'], ascending=False)
top10produce= adf
top10produce


ind = np.arange(10)
#plt.bar(intop10['Billing city'], top10['gross_sales'], color="b")
top10produce = pd.DataFrame(top10produce)

#top10produce['Billing country'].unique()



ind = np.arange(10)
#plt.bar(intop10['Billing city'], top10['gross_sales'], color="b")
plt.bar(ind,top10produce['gross_sales'], color="red")
plt.xticks(rotation=90)
plt.xticks(ind, ['United States', 'United Kingdom', 'Italy', 'Australia', 'Germany',
       'France', 'Bahrain', 'Switzerland', 'Netherlands', 'Canada'])
plt.xlabel("Count")
plt.ylabel("Country")
plt.title('Top 10 countries purchasing items (by count)')
plt.savefig("KKKKKKKKKKKKKKKKNumber_purchases_country.svg")
plt.figure(figsize=(12,12))

plt.show()

# %%
a = data.groupby('Billing country').sum()['gross_sales']
adf = a.sort_values().reset_index()[-10:]
adf = adf.sort_values(by = ['gross_sales'], ascending=False)
top10produce= adf
top10produce


ind = np.arange(10)
#plt.bar(intop10['Billing city'], top10['gross_sales'], color="b")
top10produce = pd.DataFrame(top10produce)

top10produce['Billing country'].unique()


ind = np.arange(10)
#plt.bar(intop10['Billing city'], top10['gross_sales'], color="b")
plt.bar(ind,top10produce['gross_sales'], color="orange")
plt.xticks(rotation=90)
plt.xticks(ind, ['United States', 'United Kingdom', 'Italy', 'Australia', 'Germany',
       'France', 'Bahrain', 'Switzerland', 'Netherlands', 'Canada'])
plt.xlabel("Country")
plt.ylabel("Gross Sales")
plt.title('Top 10 spending countries (by gross)')
plt.savefig("KKKKKKKKKKKKKKKKtotal_purchases_country.svg")
plt.figure(figsize=(12,12))

plt.show()

# %%
a = data.groupby('Billing country').sum()['total_sales']
adf = a.sort_values(ascending=False)
adf
# Out:
# Billing country
# United States     115889.74
# United Kingdom     29775.32
# Italy              13037.41
# Bahrain             5327.00
# France              5228.92
# Germany             4788.50
# Australia           4709.00
# Switzerland         3214.10
# Netherlands         2494.90
# Greece              2215.52
# Canada              1731.00
# Hong Kong            999.00
# Belgium              752.74
# Austria              713.70
# Qatar                713.00
# Norway               646.00
# Turkey               579.00
# Sweden               546.56
# Kuwait               544.12
# Spain                485.56
# Cyprus               405.04
# Denmark              240.34
# Ireland              224.48
# Saudi Arabia         195.20
# Czech Republic       170.80
# Japan                128.00
# South Africa         123.22
# Singapore             70.00
# Name: total_sales, dtype: float64

# %%
a = data.groupby('Billing city').count()['gross_sales']
adf = a.sort_values().reset_index()[-10:]
adf = adf.sort_values(by = ['gross_sales'], ascending=False)
top10produce= adf
top10produce


ind = np.arange(10)
#plt.bar(intop10['Billing city'], top10['gross_sales'], color="b")
top10produce = pd.DataFrame(top10produce)

print(top10produce['Billing city'].unique())


ind = np.arange(10)
#plt.bar(intop10['Billing city'], top10['gross_sales'], color="b")
plt.bar(ind,top10produce['gross_sales'], color="red")
plt.xticks(rotation=90)
plt.xticks(ind, ['New York', 'London', 'Chicago', 'Brooklyn', 'West Des Moines',
       'West Riffa', 'Roma', 'Charleston', 'Cesenatico', 'Boca Raton'])
plt.xlabel("Count")
plt.ylabel("Country")
plt.title('Top 10 cities purchasing items (by count)')
plt.savefig("KKKKKKKKKKKKKKKKNumber_purchases_city_count.svg")
plt.figure(figsize=(12,12))

plt.show()
# Out:
# ['New York' 'London' 'Chicago' 'Brooklyn' 'West Des Moines' 'West Riffa'
#  'Roma' 'Charleston' 'Cesenatico' 'Boca Raton']

# %%
a = data.groupby('Billing city').sum()['gross_sales']
adf = a.sort_values().reset_index()[-10:]
adf = adf.sort_values(by = ['gross_sales'], ascending=False)
top10country= adf

ind = np.arange(10)
#plt.bar(intop10['Billing city'], top10['gross_sales'], color="b")
top10country = pd.DataFrame(top10country)

print((top10country['Billing city'].unique()))


ind = np.arange(10)
#plt.bar(intop10['Billing city'], top10['gross_sales'], color="b")
plt.bar(ind,top10country['gross_sales'], color="orange")
plt.xticks(rotation=90)
plt.xticks(ind, ['New York' ,'London', 'Chicago' ,'West Riffa', 'Brooklyn', 'Bronxville', 'Roma',
 'Charleston' ,'Los Angeles' ,'Greenwich'])
plt.xlabel("Gross Sales")
plt.ylabel("Top 10 cities")
plt.title('Top 10 cities contributing to gross sales')
plt.savefig("KKKKKKKKKKKKKKKKtop10cities_gross_sales.svg")
plt.figure(figsize=(12,12))

plt.show()
# Out:
# ['New York' 'London' 'Chicago' 'West Riffa' 'Brooklyn' 'Bronxville' 'Roma'
#  'Charleston' 'Los Angeles' 'Greenwich']

# %%
data
## best sales of dresses?
# Out:
#                                       product_title    product_vendor  \
# 0                   ROMANTIC EMBROIDERY ANITA DRESS  Emporio Sirenuse
# 1                                      Diana Garden  Emporio Sirenuse
# 2     Hanging wrought iron candelabra - 18 branches  Emporio Sirenuse
# 3                                      Diana Garden  Emporio Sirenuse
# 4                                      Diana Garden  Emporio Sirenuse
# 5                                Anita Acanto dress  Emporio Sirenuse
# 6                   ROMANTIC EMBROIDERY ANITA SKIRT  Emporio Sirenuse
# 7          Wrought Iron Candle Holder - 12 branches  Emporio Sirenuse
# 8                          Ab Reglan (Mari) Isadora  Emporio Sirenuse
# 9                                   TIE & DYE ANGIE  Emporio Sirenuse
# 10                   Square Silk Pillow Red Stripes  Emporio Sirenuse
# 11                          SQUARE SILK PILLOW BLUE  Emporio Sirenuse
# ...

# %%
ind = np.arange(10)
#plt.bar(intop10['Billing city'], top10['gross_sales'], color="b")
plt.bar(ind,top10['gross_sales'], color="b")
plt.xticks(rotation=90)
plt.xticks(ind, ['New York', 'London', 'Chicago', 'West Riffa', 'Brooklyn',
       'Bronxville', 'Roma', 'Charleston', 'Los Angeles', 'Greenwich'])
plt.xlabel("Gross Sales")
plt.ylabel("Cities")
plt.title('Top 10 cities contributing to gross sales")
plt.figure(figsize=(12,12))
plt.savefig("top10citiesgrosssales.svg")
plt.show()
# Out:
#   File "<ipython-input-16-db7817399099>", line 9
#     plt.title('Top 10 cities contributing to gross sales")
#                                                           ^
# SyntaxError: EOL while scanning string literal

# %%
"""
labels2, values2 = zip(*Counter(delay['Billing city']).items())
indexes2 = np.arange(len(labels2))
width = 1
plt.bar(indexes2, values2, width, color="r")
plt.xticks(indexes2 + width * 0.5, labels2)
plt.xlabel("Count")
plt.ylabel("Country")
plt.xticks(rotation=90)
plt.title('Top US cities spending')
plt.figure(figsize=(12,12))
plt.savefig("Number_purchases_country.svg")
plt.show()"""
# Out:
# '\nlabels2, values2 = zip(*Counter(delay[\'Billing city\']).items())\nindexes2 = np.arange(len(labels2))\nwidth = 1\nplt.bar(indexes2, values2, width, color="r")\nplt.xticks(indexes2 + width * 0.5, labels2)\nplt.xlabel("Count")\nplt.ylabel("Country")\nplt.xticks(rotation=90)\nplt.title(\'Top US cities spending\')\nplt.figure(figsize=(12,12))\nplt.savefig("Number_purchases_country.svg")\nplt.show()'

# %%
"""~~~~~~~~~~~~~DONE~~~~~~~~~~~~~"""


data['discounts1']= data['discounts']*-1
a = data.groupby('Billing country').mean()['discounts1']
#adf = a.sort_values(ascending=False)
adf = a.sort_values(ascending=True).reset_index()[-10:]
adf = adf.sort_values(by = ['discounts1'], ascending=False)
top10country= adf

ind = np.arange(10)
#plt.bar(intop10['Billing city'], top10['gross_sales'], color="b")
top10country = pd.DataFrame(top10country)

#print(top10country['Billing country'].unique())

ind = np.arange(10)
#plt.bar(intop10['Billing city'], top10['gross_sales'], color="b")
plt.bar(ind,top10country['discounts1'], color="green")
plt.xticks(rotation=90)
plt.xticks(ind, ['Italy', 'France' ,'Denmark', 'Czech Republic', 'Cyprus', 'Canada' ,'Belgium'
 ,'Bahrain' ,'Austria', 'United Kingdom'])
plt.xlabel("Countries")
plt.ylabel("Percent Discount")
plt.title('Only Italians get discounts')
plt.savefig("KKKKKKKKKKKKKKKKonlyitaliansgetdiscounts.svg")
plt.figure(figsize=(12,12))

plt.show()
"""~~~~~~~~~~~~~DONE~~~~~~~~~~~~~"""
# Out:
# '~~~~~~~~~~~~~DONE~~~~~~~~~~~~~'

# %%
data
# Out:
#                                       product_title    product_vendor  \
# 0                   ROMANTIC EMBROIDERY ANITA DRESS  Emporio Sirenuse
# 1                                      Diana Garden  Emporio Sirenuse
# 2     Hanging wrought iron candelabra - 18 branches  Emporio Sirenuse
# 3                                      Diana Garden  Emporio Sirenuse
# 4                                      Diana Garden  Emporio Sirenuse
# 5                                Anita Acanto dress  Emporio Sirenuse
# 6                   ROMANTIC EMBROIDERY ANITA SKIRT  Emporio Sirenuse
# 7          Wrought Iron Candle Holder - 12 branches  Emporio Sirenuse
# 8                          Ab Reglan (Mari) Isadora  Emporio Sirenuse
# 9                                   TIE & DYE ANGIE  Emporio Sirenuse
# 10                   Square Silk Pillow Red Stripes  Emporio Sirenuse
# 11                          SQUARE SILK PILLOW BLUE  Emporio Sirenuse
# ...

# %%
a = data.groupby('Sales channel name').sum()['gross_sales']
adf = a.sort_values().reset_index()[-10:]
adf = adf.sort_values(by = ['gross_sales'], ascending=False)
top10country= adf

ind = np.arange(10)
#plt.bar(intop10['Billing city'], top10['gross_sales'], color="b")
top10country = pd.DataFrame(top10country)

#top10country['Year'].unique()


top10country
# Out:
#   Sales channel name  gross_sales
# 0       Online Store     198492.0

# %%
## all Online purchases, all only 2016, 2017
