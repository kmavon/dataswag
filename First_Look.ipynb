# %%
import sys
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
import statsmodels.api as sm
from statsmodels.api import OLS
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import LassoCV
import seaborn as sns
import seaborn as sns
import sklearn as sk
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
sns.set(style="ticks")
from statsmodels.tools import add_constant
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression
from sklearn import linear_model 



import sqlite3


# %matplotlib inline

# %%
# %%bash
# ~ cd
# Out:
# bash: line 1: /Users/kimia: is a directory

# %%
db = sqlite3.connect('DumpThesisData20180114.sql')
cursor = db.cursor()

# %%
# This strange command turns out FOREIGN KEY support in SQLite.
# By default, this support is off.
# We'll talk about foreign keys later on.  Just setting things up here.
cursor.execute("PRAGMA foreign_keys=1")

# %%
db = sqlite3.connect('DumpThesisData20180114.sql')
cursor = db.cursor()

cursor.execute("PRAGMA foreign_keys=1")

cursor.execute('''CREATE TABLE candidates (
               id INTEGER PRIMARY KEY NOT NULL, 
               first_name TEXT, 
               last_name TEXT, 
               middle_init TEXT, 
               party TEXT NOT NULL)''')

db.commit() # Commit changes to the database

cursor.execute('''CREATE TABLE contributors (
            'shortcode' varchar(12) DEFAULT NULL,
            'id_post' bigint(20) DEFAULT NULL,
            'username'varchar(45) DEFAULT NULL,
            'id_comment' bigint(20) NOT NULL
            'text' longtext,
            'created_at' double DEFAULT NULL,
            PRIMARY KEY ('id_comment')
             ) ENGINE=InnoDB DEFAULT CHARSET=latin1:
            ''')

db.commit()
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-14-16e39a4a9d19> in <module>()
#       9                last_name TEXT,
#      10                middle_init TEXT,
# ---> 11                party TEXT NOT NULL)''')
#      12
#      13 db.commit() # Commit changes to the database
#
# DatabaseError: file is encrypted or is not a database

# %%
data = pd.read_csv('tribe_dynamics_data1.csv')

# %%
data
# Out:
#        Unnamed: 0  Unnamed: 0.1  brand_id                        worker_id  \
# 0               0             0     18792  TRIBE_103_allayne.low@gmail.com
# 1               1             1     18792  TRIBE_103_allayne.low@gmail.com
# 2               2             2     18792  TRIBE_103_allayne.low@gmail.com
# 3               3             3     18792  TRIBE_103_allayne.low@gmail.com
# 4               4             4     18792  TRIBE_103_allayne.low@gmail.com
# 5               5             5     18792  TRIBE_103_allayne.low@gmail.com
# 6               6             6     18792  TRIBE_103_allayne.low@gmail.com
# 7               7             7     18792  TRIBE_103_allayne.low@gmail.com
# 8               8             8     18792  TRIBE_103_allayne.low@gmail.com
# 9               9             9     18792  TRIBE_103_allayne.low@gmail.com
# 10             10            10     18792  TRIBE_103_allayne.low@gmail.com
# ...

# %%
data/co
